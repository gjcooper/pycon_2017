# %% [markdown]
# ## Scotch
#
# The scraping notebook walked through some basic web scraping with html that was fairly straightforward and well behaved to show you the basics of the involved libraries. And there are a lot of nicely written tutorials on the web where you can see a polished version of what people did for scraping. But the question I was struggling with while putting this together was how do you really teach someone to scrape? And what is a good site to teach with?
#
# While I was thinking about it, I recieved the weekly email from one of my favorite online retailers, [Drink Up NY](http://www.drinkupny.com/Default.asp). Since I am quite fond of their inventory and I had scraping on the brain, I thought I would see if I could scrape the data (and I didn't see any good reason [why I shouldn't](http://www.drinkupny.com/robots.txt)). As I was playing around with this notebook I thought it might be a good way to demonstrate a thought process for approaching scraping. This is not a definitive way to scrape, it is just the way *I* approached *this* page sitting around on my couch the week before this tutorial. Like anything in Python, there are a lot of ways to accomplish something.
#
# I can read and write some html and I have broken some CSS on WordPress before, but I am not a web dev. I would call myself barely competent in that realm. If I were, I imagine this would go a lot faster sometimes. I do like tinkering around and trying things though, so that is how I approach scraping and what I will demonstrate here.
#
# So, let's see what is going on with Scotch prices on Drink Up NY!
#
# ## Update
#
# Drink Up NY not available so trying with another site (SMWS Shop)

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# I am using [requests](http://docs.python-requests.org/en/master/) here, but I could have just as easily used [urllib](https://docs.python.org/3.5/library/urllib.html).
#
# First, we need to get the page. If you navigate around the [Drink Up NY](http://www.drinkupny.com/Default.asp) site a bit, you can see they have a lot of drop down menus. I am just intereted in the [Scotch](https://www.drinkupny.com/single-malt-scotch-whisky-s/77.htm) page right now. I navigated here through the "SPIRITS ETC" - "Whisk(e)y" - "Scotch Whisky" links. For scraping, I am going to change the "per page" option to "120 per page" so I have everything on one page.

# %%
html_file = "https://www.smws.com.au/shop/?product_count=60"
html_rpt = requests.get(html_file, headers={'User-Agent': 'GCLearn (Learning crawler for Gavin Cooper: gavincooper.net)'})

# %%
if html_rpt.status_code == 200:
    print(html_rpt.content)
else:
    print(html_rpt.status_code)
# Out:
# b'<!DOCTYPE html>\n<html class="avada-html-layout-wide" lang="en-AU" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">\n<head>\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>\n\t<meta name="viewport" content="width=device-width, initial-scale=1" />\n\t<title>Products &#8211; The Scotch Malt Whisky Society Australia</title>\n<link rel=\'dns-prefetch\' href=\'//chimpstatic.com\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="The Scotch Malt Whisky Society Australia &raquo; Feed" href="https://www.smws.com.au/feed/" />\n<link rel="alternate" type="application/rss+xml" title="The Scotch Malt Whisky Society Australia &raquo; Comments Feed" href="https://www.smws.com.au/comments/feed/" />\n<link rel="alternate" type="text/calendar" title="The Scotch Malt Whisky Society Australia &raquo; iCal Feed" href="https://www.smws.com.au/events/?ical=1" />\n\t\t\n\t\t\n\t\t\n\t\t\n\t\t\t\t<link rel="alternate" type="application/rss+xml" title="The Scotch Malt Whisky Society Australia &raquo; Products Feed" href="https://www.smws.com.au/shop/feed/" />\n\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/11\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/11\\/svg\\/","svgExt":".svg","source":{"concatemoji":"http:\\/\\/www.smws.com.au\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=4.9.9"}};\n\t\t\t!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);\n\t\t</script>\n\t\t<style type="text/css">\nimg.wp-smiley,\nimg.emoji {\n\tdisplay: inline !important;\n\tborder: none !important;\n\tbox-shadow: none !important;\n\theight: 1em !important;\n\twidth: 1em !important;\n\tmargin: 0 .07em !important;\n\tvertical-align: -0.1em !important;\n\tbackground: none !important;\n\tpadding: 0 !important;\n}\n</style>\n<link rel=\'stylesheet\' id=\'dashicons-css\'  href=\'http://www.smws.com.au/wp-includes/css/dashicons.min.css?ver=4.9.9\' type=\'text/css\' media=\'all\' />\n<style id=\'dashicons-inline-css\' type=\'text/css\'>\n[data-font="Dashicons"] ...

# %% [markdown]
# It worked. Let's parse and prettify it.

# %%
soup = BeautifulSoup(html_rpt.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="avada-html-layout-wide" lang="en-AU" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Products – The Scotch Malt Whisky Society Australia
#   </title>
#   <link href="//chimpstatic.com" rel="dns-prefetch"/>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="https://www.smws.com.au/feed/" rel="alternate" title="The Scotch Malt Whisky Society Australia » Feed" type="application/rss+xml"/>
#   <link href="https://www.smws.com.au/comments/feed/" rel="alternate" title="The Scotch Malt Whisky Society Australia » Comments Feed" type="application/rss+xml"/>
#   <link href="https://www.smws.com.au/events/?ical=1" rel="alternate" title="The Scotch Malt Whisky Society Australia » iCal Feed" type="text/calendar"/>
#   <link href="https://www.smws.com.au/shop/feed/" rel="alternate" title="The Scotch Malt Whisky Society Australia » Products Feed" type="application/rss+xml"/>
#   <script type="text/javascript">
#    window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/www.smws.com.au\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.9.9"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
#   </script>
#   <style type="text/css">
#    img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
#   </style>
#   <link href="http://www.smws.com.au/wp-includes/css/dashicons.min.css?ver=4.9.9" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
#   <style id="dashicons-inline-css" type="text/css">
#    [data-font="Dashicons"]:before {font-family: 'Dashicons' !important;content: attr(data-icon) !important;speak: none !important;font-weight: normal !important;font-variant: normal !important;text-transform: none !important;line-height: 1 !important;font-style: normal !important;-webkit-font-smoothing: antialiased !important;-moz-osx-font-smoothing: grayscale !important;}
#   </style>
#   <link href="http://www.smws.com.au/wp-content/plugins/event-tickets-plus/src/resources/css/tickets.min.css?ver=4.8.3" id="event-tickets-plus-tickets-css-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.smws.com.au/wp-content/plugins/pb-add-on-mailchimp-integration/assets/css/style-front-end.css?ver=4.9.9" id="wppb-mailchimp-integration-css" media="all" rel="stylesheet" type="text/css"/>
#   <style id="woocommerce-inline-inline-css" type="text/css">
#    .woocommerce form .form-row .required { visibility: visible; }
#   </style>
#   <link href="http://www.smws.com.au/wp-content/plugins/fusion-core/css/style.min.css?ver=4.9.9" id="fusion-core-style-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.smws.com.au/wp-content/plugins/yith-woocommerce-badge-management-premium/assets/css/frontend.css?ver=1.3.17" id="yith_wcbm_badge_style-css" media="all" rel="stylesheet" type="text/css"/>
#   <style id="yith_wcbm_badge_style-inline-css" type="text/css">
#    .yith-wcbm-badge-29614{ top: -5px;bottom: auto;left: -9px;right: auto; opacity: 1; }.yith-wcbm-badge-29614 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-22304{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-22304 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-21537{ top: 0px;bottom: auto;left: 19px;right: auto; opacity: 1; }.yith-wcbm-badge-21537 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-17855{ top: auto;bottom: 0px;left: calc(50% - 55px);right: auto; opacity: 1; }.yith-wcbm-badge-17855 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-29019{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-29019 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-32212{ top: 1px;bottom: auto;left: 2px;right: auto; opacity: 1; }.yith-wcbm-badge-32212 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-21874{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-21874 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-4659{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 0.92; }.yith-wcbm-badge-4659 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-5977{ top: -9px;bottom: auto;left: -3px;right: auto; opacity: 1; }.yith-wcbm-badge-5977 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-29020{ top: -15px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-29020 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-21536{ top: 0px;bottom: auto;left: auto;right: 0px; opacity: 1; }.yith-wcbm-badge-21536 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-21470{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-21470 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-18607{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-18607 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-6441{ top ...
#   </style>
#   <link href="//fonts.googleapis.com/css?family=Open+Sans%3A400%2C600%2C700%2C800%2C300&amp;ver=4.9.9" id="googleFontsOpenSans-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.smws.com.au/wp-content/plugins/woocommerce-memberships/assets/css/frontend/wc-memberships-frontend.min.css?ver=1.12.2" id="wc-memberships-frontend-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.smws.com.au/wp-content/themes/Avada/assets/css/style.min.css?ver=5.7.2" id="avada-stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.smws.com.au/wp-content/themes/Avada-Child-Theme/style.css?ver=4.9.9" id="child-style-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.smws.com.au/wp-content/themes/Avada-Child-Theme/css/magnific-popup.css?ver=4.9.9" id="magnific-popup-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.smws.com.au/wp-content/themes/Avada/includes/lib/assets/fonts/fontawesome/font-awesome.min.css?ver=5.7.2" id="fontawesome-css" media="all" rel="stylesheet" type="text/css"/>
#   <!--[if lte IE 9]>
# <link rel='stylesheet' id='avada-IE-fontawesome-css'  href='http://www.smws.com.au/wp-content/themes/Avada/includes/lib/assets/fonts/fontawesome/font-awesome.min.css?ver=5.7.2' type='text/css' media='all' />
# <![endif]-->
#   <!--[if IE]>
# <link rel='stylesheet' id='avada-IE-css'  href='http://www.smws.com.au/wp-content/themes/Avada/assets/css/ie.min.css?ver=5.7.2' type='text/css' media='all' />
# <![endif]-->
#   <link href="http://www.smws.com.au/wp-content/plugins/fusion-builder/css/fusion-shortcodes.min.css?ver=1.7.2" id="fusion-builder-shortcodes-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.smws.com.au/wp-content/plugins/fusion-builder/assets/css/animations.min.css?ver=1.7.2" id="fusion-builder-animations-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.smws.com.au/wp-content/plugins/fusion-builder/assets/css/ilightbox.min.css?ver=1.7.2" id="fusion-builder-ilightbox-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="http://www.smws.com.au/wp-content/plugins/profile-builder-pro/assets/css/style-front-end.css?ver=2.9.2" id="wppb_stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="http://www.smws.com.au/wp-includes/js/jquery/jquery.js?ver=1.12.4" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript">
#   </script>
#   <link href="https://www.smws.com.au/wp-json/" rel="https://api.w.org/"/>
#   <link href="https://www.smws.com.au/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#   <link href="http://www.smws.com.au/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#   <meta content="v1" name="et-api-version">
#    <meta content="https://www.smws.com.au" name="et-api-origin">
#     <link href="https://www.smws.com.au/wp-json/tribe/tickets/v1/" rel="https://theeventscalendar.com/"/>
#     <meta content="v1" name="tec-api-version">
#      <meta content="https://www.smws.com.au" name="tec-api-origin">
#       <link href="https://www.smws.com.au/wp-json/tribe/events/v1/" rel="https://theeventscalendar.com/"/>
#       <meta content="always" name="referrer"/>
#       <noscript>
#        <style>
#         .woocommerce-product-gallery{ opacity: 1 !important; }
#        </style>
#       </noscript>
#       <style id="fusion-stylesheet-inline-css" type="text/css">
#        @font-face {
#   font-family: 'Roboto';
#   font-style: italic;
#   font-weight: 400;
#   src: local('Roboto Italic'), local('Roboto-Italic'), url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xEIzc.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: italic;
#   font-weight: 700;
#   src: local('Roboto Bold Italic'), local('Roboto-BoldItalic'), url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51TzBic2CsE.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 400;
#   src: local('Roboto'), local('Roboto-Regular'), url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu7mxP.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 500;
#   src: local('Roboto Medium'), local('Roboto-Medium'), url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fCBc9.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 700;
#   src: local('Roboto Bold'), local('Roboto-Bold'), url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfCBc9.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Rufina';
#   font-style: normal;
#   font-weight: 400;
#   src: local('Rufina'), local('Rufina-Regular'), url(//fonts.gstatic.com/s/rufina/v5/Yq6V-LyURyLy-aKCpB5g.ttf) format('truetype');
# }
# /********* Compiled CSS - Do not edit *********/@font-face{font-family:;src:;font-weight: normal;font-style: normal;}.group{zoom:1}.group:after,.group:before{content:" ";display:table}.group:after{clear:both}.woocommerce input[type=number]{-moz-appearance:textfield}.woocommerce input[type=number].qty::-webkit-inner-spin-button,.woocommerce input[type=number].qty::-webkit-outer-spin-button{-webkit-appearance:none;margin:0}.woocommerce-info,.woocommerce-message{margin-bottom:30px;padding:20px 0 20px 16px;border:none;text-align:left}.woocommerce-info:before,.woocommerce-message:before{position:absolute;margin-left:-16px;font-family:IcoMoon;content:'\f05d'}.woocommerce-info .wc-forward,.woocommerce-message .wc-forward{float:right;text-shadow:none}.woocommerce-info .wc-forward:before,.woocommerce-message .wc-forward:before{font-family:IcoMoon;content:'\f07a';margin-right:6px;color:inherit}.woocommerce-error{list-style:none;padding:0}.woocommerce-error li{margin-bottom:15px;padding:8px;position:relative;text-align:center}.woocommerce .avada-order-details .order-again .button,.woocommerce .login .button,.woocommerce .lost_reset_password input[type=submit],.woocommerce .register .button,.woocommerce .shipping-calculator-form .button,.woocommerce button.button,.woocommerce button.fusion-button{text-transform:uppercase;text-align:center;margin:0;cursor:pointer}.woocommerce .lost_reset_password input[type=submit]{border:0}.woocommerce .button{cursor:pointer}.woocommerce .single_add_to_cart_button,.woocommerce button.button{margin-top:-1px}.woocommerce .avada-shipping-calculator-form .button,.woocommerce .shipping-calculator-form .button{float:right;margin-top:0}.woocommerce-checkout .woocommerce .woocommerce-form-login{margin-bottom:20px}.woocommerce .login .form-row{text-align:initial;margin:0 20px 0 15px;float:right}.woocommerce .login .form-row.form-row-first,.woocommerce .login .form-row.form-row-last{margin:0 0 20px;float:none}.woocommerce .login .button{margin-left:15px}.woocommerce .login .inline{float:left;margin-top:5px}.woocommerce .login .lost_password{float:right;margin-top:5px}.woocommerce #customer_login .login .form-row{display:inline-block;float:none;margin:0 18px 0 0;text-align:initial}.woocommerce #customer_login .login .form-row.form-row-wide{display:block;margin:0 0 20px}.woocommerce #customer_login .login .button{margin-left:0}.woocommerce #customer_login .login .inline{display:inline-block;vertical-align:middle;float:none;margin-top:0;margin-left:15px;line-height:1}.woocommerce #customer_login .login .inline .woocommerce-Input,.woocommerce #customer_login .login .inline input{vertical-align:middle;margin:0 3px}.woocommerce #customer_login .login .lost_password{display:inline-block;vertical-align:middle;float:none;margin:0}.woocommerce #customer_login .register .form-row:last-child{margin-bottom:0}.woocommerce .checkout_coupon{margin-bottom:40px;display:-webkit-flex!important;display:-ms-flexbox!important;display:flex!important;-webkit-align-items:center;-ms-flex-align:center;align-items:center;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between}.woocommerce .checkout_coupon .promo-code-heading{margin:0;padding:0;border:none}.woocommerce .checkout_coupon .coupon-contents{display:-webkit-flex!important;display:-ms-flexbox!important;display:flex!important;-webkit-align-items:center;-ms-flex-align:center;align-items:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-order:4;-ms-flex-order:4;order:4;margin:0 -7.5px}.woocommerce .checkout_coupon .coupon-input{width:240px;margin:0;padding:5px 7.5px}.woocommerce .checkout_coupon .coupon-input .input-text{margin:0;padding:8px 15px}.woocommerce .checkout_coupon .coupon-button{margin:0;padding:5px 7.5px}.woocommerce-ordering{display:none}.woocommerce-invalid:after{display:inline-block;margin-top:7px;color:red}.woocommerce .woocommerce-container{ ...
#     height: 40px;
# }
# .shop_table td {
#     padding: 10px 0 !important;
# }
# .shop_table thead tr th {
#     border-top: 0 none !important;
#     font-size: 13px;
#     font-weight: bold;
#     padding-bottom: 12px;
# }
# .shop_table tbody tr:last-child {
#     border-bottom: 1px solid #ddd !important;
# }
# .shop_table .product-quantity {
#     text-align: center;
#     width: 15%;
# }
# .shop_table .product-name {
#     width: 45%;
# }
# .cart_totals table th {
#     padding-bottom: 20px;
#     width: 25%;
# }
# .woocommerce-cart .cart_totals .shop_table .cart-subtotal {
#     border-bottom: 0 none;
#     display: none !important;
# }
# .woocommerce-cart .cart_totals .shop_table .recurring-totals {
#     border-bottom: 0 none;
#     display: none !important;
# }
# .checkout .shop_table tfoot th {
#     padding: 15px;
#     text-align: right;
#     width: 70% !important;
# }
# .checkout .shop_table tfoot td {
#     padding: 15px;
#     text-align: right;
# }
# .checkout .shop_table tfoot tr {
#     border-bottom: 1px solid #ddd;
# }
# .payment_methods li img {
#     clear: both;
#     float: left;
# }
# form.cart {
#     margin-bottom: 40px;
#     margin-top: 5px !important;
# }
# .checkout .payment_methods .payment_box {
#     clear: both;
#     height: 220px;
#     margin-top: 10px;
#     padding: 20px;
# }
# .coupon .input-text {
#     float: left;
#     margin-left: 0;
#     margin-right: 0;
#     margin-top: 15px;
#     padding-left: 15px;
#     padding-right: 15px;
#     width: 75%;
# }
# .woocommerce .cc-checkout {
#     float: left;
#     margin-right: 30px;
# }
# .order_details {
#     float: left;
#     margin-right: 30px;
# }
# .checkout .cart-subtotal {
#     display: none;
# }
# .checkout .recurring-totals {
#     display: none;
# }
# .gift-certificate {
#     float: left;
#     margin: 0;
#     padding-left: 25px;
#     padding-right: 25px;
#     width: 100%;
# }
# .tribe-events-style-full table.tribe-events-tickets td {
#     border-bottom: 0 none;
# }
# table.tribe-events-tickets td {
#     border-top: 1px solid #ddd;
#     float: left;
#     padding: 8px 10px 8px 0;
#     vertical-align: middle;
#     width: 100%;
# }
# .tribe-tickets-remaining {
#     vertical-align: middle;
#     float: right;
# }
# .tribe-tickets-attendees-list-optout label {
#     font-size: 12px;
#     margin-left: 5px;
# }
# .cart_totals table {
#     margin-bottom: 20px;
#     text-align: left;
#     width: 100%;
# }
# .shop_table {
#     margin-bottom: 30px;
#     text-align: left;
#     width: 100%;
# }
# h2.tribe-events-tickets-title {
#     background-color: #aace4e;
#     padding: 9px 15px;
# }
# h2.tribe-events-tickets-title {
#     color: #333333;
# }
# h2.tribe-events-tickets-title {
#     font-size: 17px;
# }
# form.checkout label {
#     display: inline-block;
#     margin-bottom: 2px;
#     padding-right: 10px;
# }
# .quantity .minus, .quantity .plus, .quantity .qty {
#     font-size: 18px;
#     height: 40px;
#     line-height: 21px;
#     width: 40px;
# }
# .coupon .input-text {
#     float: left;
#     height: 59px;
#     margin-left: 0;
#     margin-right: 0;
#     margin-top: 1px;
#     padding-left: 15px;
#     padding-right: 15px;
#     width: 75%;
# }
# .fusion-page-title-bar h1 {
#     font-size: 18px;
# }
# #wrapper #main .fusion-portfolio-content > h2.entry-title, #wrapper #main .fusion-post-content > .blog-shortcode-post-title, #wrapper #main .fusion-post-content > h2.entry-title, #wrapper #main .post > h2.entry-title, #wrapper .fusion-events-shortcode .fusion-events-meta h2, .single-product .product .product_title {
#     font-size: 28px;
# }
# .fusion-woo-product-design-clean .products .product-title {
#     font-size: 22px;
#     font-style: normal;
# }
# .woocommerce_account_subscriptions {
#     display: none;
# }
# .woocommerce span.onsale.wc-memberships-member-discount {
#     display: none !important;
# }@media only screen and (max-width: 644px){.fusion-blog-layout-grid-6 .fusion-post-grid,.fusion-grid-6 .fusion-grid-column,.fusion-portfolio-six .fusion-portfolio-post{width:100%!important}.fusion-blog-layout-grid-6 .fusion-post-grid.fusion-element-landscape .fusion-masonry-element-container,.fusion-grid-6 .fusion-grid-column.fusion-element-landscape .fusion-masonry-element-container,.fusion-portfolio-six .fusion-portfolio-post.fusion-element-landscape .fusion-masonry-element-container{padding-top:65%!important}.fusion-blog-layout-grid-6 .fusion-post-grid.fusion-element-grid .fusion-masonry-element-container,.fusion-grid-6 .fusion-grid-column.fusion-element-grid .fusion-masonry-element-container,.fusion-portfolio-six .fusion-portfolio-post.fusion-element-grid .fusion-masonry-element-container{padding-top:100%!important}}@media only screen and (max-width: 735px){.fusion-blog-layout-grid .fusion-post-grid,.fusion-grid-column,.fusion-portfolio-post{width:100%!important}.fusion-blog-layout-grid .fusion-post-grid.fusion-element-landscape .fusion-masonry-element-container,.fusion-grid-column.fusion-element-landscape .fusion-masonry-element-container,.fusion-portfolio-post.fusion-element-landscape .fusion-masonry-element-container{padding-top:65%!important}.fusion-blog-layout-grid .fusion-post-grid.fusion-element-grid .fusion-masonry-element-container,.fusion-grid-column.fusion-element-grid .fusion-masonry-element-container,.fusion-portfolio-post.fusion-element-grid .fusion-masonry-element-container{padding-top:100%!important}.fusion-portfolio-grid:not(.fusion-portfolio-text) .fusion-portfolio-post .fusion-image-wrapper{display:block;text-align:center}.fusion-blog-layout-grid-6 .fusion-post-grid,.fusion-grid-6 .fusion-grid-column,.fusion-portfolio-six .fusion-portfolio-post{width:50%!important}.fusion-blog-layout-grid-6 .fusion-post-grid.fusion-element-landscape,.fusion-grid-6 .fusion-grid-column.fusion-element-landscape,.fusion-portfolio-six .fusion-portfolio-post.fusion-element-landscape{width:100%!important}}@media only screen and (min-width: 735px) and (max-width: 826px){.fusion-blog-layout-grid-6 .fusion-post-grid,.fusion-grid-6 .fusion-grid-column,.fusion-portfolio-six .fusion-portfolio-post{width:33.3333333333%!important}.fusion-blog-layout-grid-6 .fusion-post-grid.fusion-element-landscape,.fusion-grid-6 .fusion-grid-column.fusion-element-landscape,.fusion-portfolio-six .fusion-portfolio-post.fusion-element-landscape{width:66.6666666666%!important}.fusion-blog-layout-grid-3 .fusion-post-grid,.fusion-blog-layout-grid-4 .fusion-post-grid,.fusion-blog-layout-grid-5 .fusion-post-grid,.fusion-grid-3 .fusion-grid-column,.fusion-grid-4 .fusion-grid-column,.fusion-grid-5 .fusion-grid-column,.fusion-portfolio-five .fusion-portfolio-post,.fusion-portfolio-four .fusion-portfolio-post,.fusion-portfolio-masonry .fusion-portfolio-post,.fusion-portfolio-three .fusion-portfolio-post{width:50%!important}.fusion-blog-layout-grid-3 .fusion-post-grid.fusion-element-landscape,.fusion-blog-layout-grid-4 .fusion-post-grid.fusion-element-landscape,.fusion-blog-layout-grid-5 .fusion-post-grid.fusion-element-landscape,.fusion-grid-3 .fusion-grid-column.fusion-element-landscape,.fusion-grid-4 .fusion-grid-column.fusion-element-landscape,.fusion-grid-5 .fusion-grid-column.fusion-element-landscape,.fusion-portfolio-five .fusion-portfolio-post.fusion-element-landscape,.fusion-portfolio-four .fusion-portfolio-post.fusion-element-landscape,.fusion-portfolio-masonry .fusion-portfolio-post.fusion-element-landscape,.fusion-portfolio-three .fusion-portfolio-post.fusion-element-landscape{width:100%!important}}@media only screen and (min-width: 826px) and (max-width: 917px){.fusion-blog-layout-grid-6 .fusion-post-grid,.fusion-grid-6 .fusion-grid-column,.fusion-portfolio-six .fusion-portfolio-post{width:25%!important}.fusion-blog-layout-grid-6 .fusion-post-grid.fusion-element-landscape,.fusion-grid-6 .fusion-grid-column.fusion-element-landscape,.fusion-portfolio-si ...
#       </style>
#       <!-- WooCommerce Google Analytics Integration -->
#       <script type="text/javascript">
#        var gaProperty = 'UA-47772714-1';
# 			var disableStr = 'ga-disable-' + gaProperty;
# 			if ( document.cookie.indexOf( disableStr + '=true' ) > -1 ) {
# 				window[disableStr] = true;
# 			}
# 			function gaOptout() {
# 				document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 				window[disableStr] = true;
# 			}
#       </script>
#       <script type="text/javascript">
#        (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga( 'create', 'UA-47772714-1', 'auto' );ga( 'set', 'anonymizeIp', true );
# 		ga( 'set', 'dimension1', 'no' );
# ga( 'require', 'ecommerce', 'ecommerce.js');
#       </script>
#       <!-- /WooCommerce Google Analytics Integration -->
#       <script type="text/javascript">
#        var doc = document.documentElement;
# 		doc.setAttribute('data-useragent', navigator.userAgent);
#       </script>
#       <script>
#        (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-47772714-1', 'auto');
#   ga('send', 'pageview');
#       </script>
#       <!-- Global site tag (gtag.js) - Google Analytics -->
#       <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-119539316-1">
#       </script>
#       <script>
#        window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-119539316-1');
#       </script>
#       <script>
#        (function(w,d,t,r,u){var f,n,i;w[u]=w[u]||[],f=function(){var o={ti:"25019964"};o.q=w[u],w[u]=new UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var s=this.readyState;s&&s!=="loaded"&&s!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");
#       </script>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="archive post-type-archive post-type-archive-product woocommerce woocommerce-page woocommerce-no-js tribe-no-js yith-wcbm-theme-avada fusion-image-hovers fusion-body ltr fusion-sticky-header no-tablet-sticky-header no-mobile-sticky-header no-mobile-slidingbar fusion-disable-outline layout-wide-mode has-sidebar fusion-top-header menu-text-align-left fusion-woo-product-design-clean mobile-menu-design-classic fusion-show-pagination-text fusion-header-layout-v3 avada-responsive avada-footer-fx-bg-parallax fusion-search-form-classic fusion-avatar-square">
#   <a class="skip-link screen-reader-text" href="#content">
#    Skip to content
#   </a>
#   <div class="" id="wrapper">
#    <div id="home" style="position:relative;top:-1px;">
#    </div>
#    <header class="fusion-header-wrapper fusion-header-shadow">
#     <div class="fusion-header-v3 fusion-logo-left fusion-sticky-menu- fusion-sticky-logo- fusion-mobile-logo-1 fusion-mobile-menu-design-classic">
#      <div class="fusion-secondary-header">
#       <div class="fusion-row">
#        <div class="fusion-alignleft">
#         <div class="fusion-contact-info">
#          Phone: 02 9974 3046
#          <span class="fusion-header-separator">
#           |
#          </span>
#          <a href="/cdn-cgi/l/email-protection#7e585d4f4e4b45585d4f4f4e4518585d4f4f4f45585d484a450d13585d4f4f47450d50585d474745585d4f4f4f45585d4f4e4745501f0b">
#           info@smws.com.au
#          </a>
#         </div>
#        </div>
#        <div class="fusion-alignright">
#         <div class="fusion-social-links-header">
#          <div class="fusion-social-networks">
#           <div class="fusion-social-networks-wrapper">
#            <a class="fusion-social-network-icon fusion-tooltip fusion-facebook fusion-icon-facebook" data-placement="bottom" data-title="Facebook" data-toggle="tooltip" href="https://www.facebook.com/Australiansmws" rel="noopener noreferrer" style="color:#ffffff;" target="_blank" title="Facebook">
#             <span class="screen-reader-text">
#              Facebook
#             </span>
#            </a>
#            <a class="fusion-social-network-icon fusion-tooltip fusion-instagram fusion-icon-instagram" data-placement="bottom" data-title="Instagram" data-toggle="tooltip" href="https://www.instagram.com/smws_aus/" rel="noopener noreferrer" style="color:#ffffff;" target="_blank" title="Instagram">
#             <span class="screen-reader-text">
#              Instagram
#             </span>
#            </a>
#            <a class="fusion-social-network-icon fusion-tooltip fusion-twitter fusion-icon-twitter" data-placement="bottom" data-title="Twitter" data-toggle="tooltip" href="https://twitter.com/SMWS_Australia" rel="noopener noreferrer" style="color:#ffffff;" target="_blank" title="Twitter">
#             <span class="screen-reader-text">
#              Twitter
#             </span>
#            </a>
#            <a class="fusion-social-network-icon fusion-tooltip fusion-linkedin fusion-icon-linkedin" data-placement="bottom" data-title="LinkedIn" data-toggle="tooltip" href="https://www.linkedin.com/company/scotch-malt-whisky-society-australia" rel="noopener noreferrer" style="color:#ffffff;" target="_blank" title="LinkedIn">
#             <span class="screen-reader-text">
#              LinkedIn
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="fusion-header-sticky-height">
#      </div>
#      <div class="fusion-header">
#       <div class="fusion-row">
#        <div class="fusion-logo" data-margin-bottom="15px" data-margin-left="0px" data-margin-right="0px" data-margin-top="15px">
#         <a class="fusion-logo-link" href="https://www.smws.com.au/">
#          <!-- standard logo -->
#          <img alt="The Scotch Malt Whisky Society Australia Logo" class="fusion-standard-logo" height="" retina_logo_url="" src="http://www.smws.com.au/wp-content/uploads/2017/10/SMWS-Off-Pack-Logo-Landscape-white-1.png" srcset="http://www.smws.com.au/wp-content/uploads/2017/10/SMWS-Off-Pack-Logo-Landscape-white-1.png 1x" width=""/>
#          <!-- mobile logo -->
#          <img alt="The Scotch Malt Whisky Society Australia Logo" class="fusion-mobile-logo" height="" retina_logo_url="" src="http://www.smws.com.au/wp-content/uploads/2017/10/amsllSMWS-Off-Pack-Logo-Portrait-white-copy.png" srcset="http://www.smws.com.au/wp-content/uploads/2017/10/amsllSMWS-Off-Pack-Logo-Portrait-white-copy.png 1x" width=""/>
#         </a>
#        </div>
#        <nav aria-label="Main Menu" class="fusion-main-menu">
#         <ul class="fusion-menu" id="menu-main-menu">
#          <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-2458" data-item-id="2458" id="menu-item-2458">
#           <a class="fusion-bar-highlight" href="https://www.smws.com.au/" role="menuitem">
#            <span class="menu-text">
#             Home
#            </span>
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item current_page_item menu-item-2459" data-item-id="2459" id="menu-item-2459">
#           <a class="fusion-bar-highlight" href="https://www.smws.com.au/shop/" role="menuitem">
#            <span class="menu-text">
#             Shop
#            </span>
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-2462 fusion-megamenu-menu" data-item-id="2462" id="menu-item-2462">
#           <a class="fusion-bar-highlight" href="#" role="menuitem">
#            <span class="menu-text">
#             Society
#            </span>
#            <span class="fusion-caret">
#             <i class="fusion-dropdown-indicator">
#             </i>
#            </span>
#           </a>
#           <div class="fusion-megamenu-wrapper fusion-columns-4 columns-per-row-4 columns-4 col-span-12 fusion-megamenu-fullwidth" data-maxwidth="1100">
#            <div class="row">
#             <div class="fusion-megamenu-holder" data-width="1100" style="width:1100px;">
#              <ul class="fusion-megamenu " role="menu">
#               <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-2463 fusion-megamenu-submenu fusion-megamenu-columns-4 col-lg-3 col-md-3 col-sm-3" id="menu-item-2463">
#                <div class="fusion-megamenu-title">
#                 <span class="fusion-megamenu-icon">
#                  <i class="glyphicon fa fa-key">
#                  </i>
#                 </span>
#                 MEMBERSHIP INFO
#                </div>
#                <ul class="sub-menu" role="menu">
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2475" id="menu-item-2475">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/membership/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    Membership Information
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2484" id="menu-item-2484">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/product/smws-annual-membership-subscription/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    Purchase Membership
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2482" id="menu-item-2482">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/product/smws-gift-membership/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    Purchase Gift Membership
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2472" id="menu-item-2472">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/society/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    About the Society
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-2464 fusion-megamenu-submenu fusion-megamenu-columns-4 col-lg-3 col-md-3 col-sm-3" id="menu-item-2464">
#                <div class="fusion-megamenu-title">
#                 <span class="fusion-megamenu-icon">
#                  <i class="glyphicon fa fa-comments">
#                  </i>
#                 </span>
#                 NEWS &amp; INFO
#                </div>
#                <ul class="sub-menu" role="menu">
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2483" id="menu-item-2483">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/news/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    Whiskywise
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2469" id="menu-item-2469">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/outturn-magazine-2/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    Outturn Magazine
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2468" id="menu-item-2468">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/unfiltered-magazine/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    Unfiltered Magazine
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2473" id="menu-item-2473">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/frequently-asked-questions/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    FAQ’s
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-2465 fusion-megamenu-submenu fusion-megamenu-columns-4 col-lg-3 col-md-3 col-sm-3" id="menu-item-2465">
#                <div class="fusion-megamenu-title">
#                 <span class="fusion-megamenu-icon">
#                  <i class="glyphicon fa fa-calendar">
#                  </i>
#                 </span>
#                 TASTINGS &amp; EVENTS
#                </div>
#                <ul class="sub-menu" role="menu">
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2477" id="menu-item-2477">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/our-unique-whisky/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    Our Unique Whisky
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2476" id="menu-item-2476">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/our-events/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    About Our Events
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2480" id="menu-item-2480">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/tasting-panel/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    The Tasting Panel
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2470" id="menu-item-2470">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/corporate-private-functions/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    Special Functions
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </li>
#               <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-2467 fusion-megamenu-submenu fusion-megamenu-columns-4 col-lg-3 col-md-3 col-sm-3" id="menu-item-2467">
#                <div class="fusion-megamenu-title">
#                 <span class="fusion-megamenu-icon">
#                  <i class="glyphicon fa fa-heart">
#                  </i>
#                 </span>
#                 YOUR SOCIETY
#                </div>
#                <ul class="sub-menu" role="menu">
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2474" id="menu-item-2474">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/our-team/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    Meet the Team
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2478" id="menu-item-2478">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/partner-bars/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    Partner Bars
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2479" id="menu-item-2479">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/smws-worldwide/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    Partner Bars Worldwide
#                   </span>
#                  </a>
#                 </li>
#                 <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2471" id="menu-item-2471">
#                  <a class="fusion-bar-highlight" href="https://www.smws.com.au/smws-worldwide-2/" role="menuitem">
#                   <span>
#                    <span class="fusion-megamenu-bullet">
#                    </span>
#                    SMWS Worldwide
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </li>
#              </ul>
#             </div>
#             <div style="clear:both;">
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2510" data-item-id="2510" id="menu-item-2510">
#           <a class="fusion-bar-highlight" href="https://www.smws.com.au/events/" role="menuitem">
#            <span class="menu-text">
#             Events
#            </span>
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2461" data-item-id="2461" id="menu-item-2461">
#           <a class="fusion-bar-highlight" href="https://www.smws.com.au/news/" role="menuitem">
#            <span class="menu-text">
#             Whiskywise
#            </span>
#           </a>
#          </li>
#          <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2460" data-item-id="2460" id="menu-item-2460">
#           <a class="fusion-bar-highlight" href="https://www.smws.com.au/contact-us/" role="menuitem">
#            <span class="menu-text">
#             Contact Us
#            </span>
#           </a>
#          </li>
#          <li class="menu-item fusion-dropdown-menu menu-item-has-children fusion-custom-menu-item fusion-menu-login-box" role="menuitem">
#           <a aria-haspopup="true" class="fusion-bar-highlight" href="https://www.smws.com.au/my-account/">
#            <span class="menu-text">
#             My Account
#            </span>
#            <span class="fusion-caret">
#             <i class="fusion-dropdown-indicator">
#             </i>
#            </span>
#           </a>
#           <div class="fusion-custom-menu-item-contents">
#            <form action="https://www.smws.com.au/wp-login.php?wpe-login=true" method="post" name="loginform">
#             <p>
#              <input class="input-text" id="username" name="log" placeholder="Username" type="text" value=""/>
#             </p>
#             <p>
#              <input class="input-text" id="password" name="pwd" placeholder="Password" type="password" value=""/>
#             </p>
#             <p class="fusion-remember-checkbox">
#              <label for="fusion-menu-login-box-rememberme">
#               <input id="fusion-menu-login-box-rememberme" name="rememberme" type="checkbox" value="forever">
#                Remember Me
#               </input>
#              </label>
#             </p>
#             <input name="fusion_woo_login_box" type="hidden" value="true"/>
#             <p class="fusion-login-box-submit">
#              <input class="button button-small default comment-submit" id="wp-submit" name="wp-submit" type="submit" value="Log In">
#               <input name="redirect" type="hidden" value=""/>
#              </input>
#             </p>
#            </form>
#            <a class="fusion-menu-login-box-register" href="https://www.smws.com.au/my-account/" title="Register">
#             Register
#            </a>
#           </div>
#          </li>
#          <li class="fusion-custom-menu-item fusion-menu-cart fusion-main-menu-cart" role="menuitem">
#           <a class="fusion-main-menu-icon fusion-bar-highlight" href="https://www.smws.com.au/cart/">
#            <span aria-label="View Cart" class="menu-text">
#            </span>
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <nav aria-label="Main Menu Mobile" class="fusion-mobile-nav-holder fusion-mobile-menu-text-align-center">
#        </nav>
#       </div>
#      </div>
#     </div>
#     <div class="fusion-clearfix">
#     </div>
#    </header>
#    <div id="sliders-container">
#    </div>
#    <div class="fusion-page-title-bar fusion-page-title-bar-none fusion-page-title-bar-left">
#     <div class="fusion-page-title-row">
#      <div class="fusion-page-title-wrapper">
#       <div class="fusion-page-title-captions">
#        <h1 class="entry-title">
#         Shop
#        </h1>
#       </div>
#       <div class="fusion-page-title-secondary">
#        <div class="fusion-breadcrumbs">
#         <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#          <a href="https://www.smws.com.au" itemprop="url">
#           <span itemprop="title">
#            Home
#           </span>
#          </a>
#         </span>
#         <span class="fusion-breadcrumb-sep">
#          /
# ...
#   </script>
#   <script>
#    /* <![CDATA[ */var tribe_l10n_datatables = {"aria":{"sort_ascending":": activate to sort column ascending","sort_descending":": activate to sort column descending"},"length_menu":"Show _MENU_ entries","empty_table":"No data available in table","info":"Showing _START_ to _END_ of _TOTAL_ entries","info_empty":"Showing 0 to 0 of 0 entries","info_filtered":"(filtered from _MAX_ total entries)","zero_records":"No matching records found","search":"Search:","all_selected_text":"All items on this page were selected. ","select_all_link":"Select all pages","clear_selection":"Clear Selection.","pagination":{"all":"All","next":"Next","previous":"Previous"},"select":{"rows":{"0":"","_":": Selected %d rows","1":": Selected 1 row"}},"datepicker":{"dayNames":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"dayNamesShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"dayNamesMin":["S","M","T","W","T","F","S"],"monthNames":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesShort":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthNamesMin":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"nextText":"Next","prevText":"Prev","currentText":"Today","closeText":"Done","today":"Today","clear":"Clear"}};var tribe_system_info = {"sysinfo_optin_nonce":"d49110a06a","clipboard_btn_text":"Copy to clipboard","clipboard_copied_text":"System info copied","clipboard_fail_text":"Press \"Cmd + C\" to copy"};/* ]]> */
#   </script>
#   <script type="text/javascript">
#    var c = document.body.className;
# 		c = c.replace(/woocommerce-no-js/, 'woocommerce-js');
# 		document.body.className = c;
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/event-tickets-plus/vendor/jquery.cookie/jquery.cookie.js?ver=4.8.3" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/event-tickets-plus/vendor/jquery.deparam/jquery.deparam.js?ver=4.8.3" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/event-tickets-plus/src/resources/js/meta.min.js?ver=4.8.3" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/event-tickets-plus/src/resources/js/attendees-list.min.js?ver=4.8.3" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/jquery-blockui/jquery.blockUI.min.js?ver=2.70" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/js-cookie/js.cookie.min.js?ver=2.1.4" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var woocommerce_params = {"ajax_url":"\/wp-admin\/admin-ajax.php","wc_ajax_url":"\/?wc-ajax=%%endpoint%%","min_password_strength":"1","i18n_password_error":"<span class=\"mr-red\">Please enter a stronger password.<\/span>","i18n_password_hint":"Your password must be at least <strong>6 characters long.<\/strong> To make it stronger, use upper and lower case letters, numbers and symbols."};
# /* ]]> */
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/frontend/woocommerce.min.js?ver=3.5.1" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var wc_cart_fragments_params = {"ajax_url":"\/wp-admin\/admin-ajax.php","wc_ajax_url":"\/?wc-ajax=%%endpoint%%","cart_hash_key":"wc_cart_hash_db8d27fdf6a5e3805b8971c318fccf31","fragment_name":"wc_fragments_db8d27fdf6a5e3805b8971c318fccf31","min_password_strength":"1","i18n_password_error":"<span class=\"mr-red\">Please enter a stronger password.<\/span>","i18n_password_hint":"Your password must be at least <strong>6 characters long.<\/strong> To make it stronger, use upper and lower case letters, numbers and symbols."};
# /* ]]> */
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/frontend/cart-fragments.min.js?ver=3.5.1" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var mailchimp_public_data = {"site_url":"http:\/\/www.smws.com.au","ajax_url":"https:\/\/www.smws.com.au\/wp-admin\/admin-ajax.php"};
# /* ]]> */
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/mailchimp-for-woocommerce/public/js/mailchimp-woocommerce-public.min.js?ver=2.1.11" type="text/javascript">
#   </script>
#   <script src="https://chimpstatic.com/mcjs-connected/js/users/1467ca1f7000eaf593230360d/9c8de063ae1b03f5d4864f152.js?ver=2.1.11" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-content/themes/Avada-Child-Theme/js/magnific-popup.min.js" type="text/javascript">
#   </script>
#   <!--[if IE 9]>
# <script type='text/javascript' src='http://www.smws.com.au/wp-content/themes/Avada/includes/lib/assets/min/js/general/fusion-ie9.js?ver=1'></script>
# <![endif]-->
#   <script src="http://www.smws.com.au/wp-content/uploads/fusion-scripts/289db04c06e300227b9381645134cfd5.min.js" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-includes/js/wp-embed.min.js?ver=4.9.9" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-includes/js/jquery/ui/mouse.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-includes/js/jquery/ui/slider.min.js?ver=1.11.4" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/jquery-ui-touch-punch/jquery-ui-touch-punch.min.js?ver=3.5.1" type="text/javascript">
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/accounting/accounting.min.js?ver=0.4.2" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /* <![CDATA[ */
# var woocommerce_price_slider_params = {"currency_format_num_decimals":"0","currency_format_symbol":"$","currency_format_decimal_sep":".","currency_format_thousand_sep":",","currency_format":"%s%v"};
# /* ]]> */
#   </script>
#   <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/frontend/price-slider.min.js?ver=3.5.1" type="text/javascript">
#   </script>
#   <!-- WooCommerce JavaScript -->
#   <script type="text/javascript">
#    jQuery(function($) {
#
# 			$( '.add_to_cart_button:not(.product_type_variable, .product_type_grouped)' ).click( function() {
# 				ga('send', 'event', 'Products', 'Add to Cart', ($(this).data('product_sku')) ? ($(this).data('product_sku')) : ('#' + $(this).data('product_id')));
# 			});
#
#
# ga( 'send', 'pageview' );
#  });
#   </script>
#   <div class="post-content woocommerce mfp-hide" id="register-lightbox">
#    <h2>
#     Register as a Taster!
#    </h2>
#    <form action="https://www.smws.com.au/shop/" class="wppb-user-forms wppb-register-user wppb-user-logged-out" enctype="multipart/form-data" id="wppb-register-user-lightbox" method="post">
#     <ul>
#      <li class="wppb-form-field wppb-default-name-heading" id="wppb-form-element-24">
#       <h4>
#        My Profile
#       </h4>
#       <span class="wppb-description-delimiter ">
#       </span>
#      </li>
#      <li class="wppb-form-field wppb-default-display-name-publicly-as" id="wppb-form-element-6">
#      </li>
#      <li class="wppb-form-field wppb-select" id="wppb-form-element-17">
#       <label for="salutation_title">
#        Title
#       </label>
#       <select class="custom_field_select" id="salutation_title" name="salutation_title">
#        <option class="custom_field_select_option " selected="" value="Mr">
#         Mr
#        </option>
#        <option class="custom_field_select_option " value="Mrs">
#         Mrs
#        </option>
#        <option class="custom_field_select_option " value="Ms">
#         Ms
#        </option>
#        <option class="custom_field_select_option " value="Miss">
#         Miss
#        </option>
#        <option class="custom_field_select_option " value="Dr">
#         Dr
#        </option>
#        <option class="custom_field_select_option " value="Prof">
#         Prof
#        </option>
#       </select>
#      </li>
#      <li class="wppb-form-field wppb-default-first-name" id="wppb-form-element-27">
#       <label for="first_name">
#        First Name
#        <span class="wppb-required" title="This field is required">
#         *
#        </span>
#       </label>
#       <input class="text-input default_field_firstname " id="first_name" maxlength="70" name="first_name" required="" type="text" value=""/>
#      </li>
#      <li class="wppb-form-field wppb-default-last-name" id="wppb-form-element-28">
#       <label for="last_name">
#        Surname
#        <span class="wppb-required" title="This field is required">
#         *
#        </span>
#       </label>
#       <input class="text-input default_field_lastname " id="last_name" maxlength="70" name="last_name" required="" type="text" value=""/>
#      </li>
#      <li class="wppb-form-field wppb-default-nickname" id="wppb-form-element-5">
#       <label for="nickname">
#        Nickname
#       </label>
#       <input class="text-input default_field_nickname " id="nickname" maxlength="70" name="nickname" type="text" value=""/>
#      </li>
#      <li class="wppb-form-field wppb-avatar" id="wppb-form-element-20">
#       <label for="avatar_upload">
#        Profile Picture
#       </label>
#       <a class="button wppb_upload_button" data-multiple_upload="false" data-upload_input="avatar_upload" data-upload_mn="avatar_upload" data-uploader_button_text="Select File" data-uploader_title="Profile Picture" href="#" id="upload_avatar_upload_button">
#        Upload
#       </a>
#       <input id="avatar_upload" name="avatar_upload" size="36" type="hidden" value=""/>
#       <span class="wppb-description-delimiter">
#        Upload your Avatar. Supported file types are JPG, GIF &amp; PNG.
#       </span>
#      </li>
#      <li class="wppb-form-field wppb-default-contact-info-heading" id="wppb-form-element-25">
#       <h4>
#        My Contact Details
#       </h4>
#       <span class="wppb-description-delimiter ">
#       </span>
#      </li>
#      <li class="wppb-form-field wppb-default-e-mail" id="wppb-form-element-8">
#       <label for="email">
#        E-mail
#        <span class="wppb-required" title="This field is required">
#         *
#        </span>
#       </label>
#       <input class="text-input default_field_email " id="email" maxlength="70" name="email" required="" type="email" value=""/>
#      </li>
#      <li class="wppb-form-field wppb-input" id="wppb-form-element-31">
#       <label for="phone_number">
#        Phone
#       </label>
#       <input class="extra_field_input " id="phone_number" maxlength="70" name="phone_number" type="text" value=""/>
#      </li>
#      <li class="wppb-form-field wppb-input" id="wppb-form-element-22">
#       <label for="mobile_number">
#        Mobile
#       </label>
#       <input class="extra_field_input " id="mobile_number" maxlength="70" name="mobile_number" type="text" value=""/>
#      </li>
#      <li class="wppb-form-field wppb-woocommerce-customer-billing-address" id="wppb-form-element-32">
#      </li>
#      <li class="wppb-form-field wppb-default-about-yourself-heading" id="wppb-form-element-26">
#       <h4>
#        Username / Password
#       </h4>
#       <span class="wppb-description-delimiter ">
#       </span>
#      </li>
#      <li class="wppb-form-field wppb-default-username" id="wppb-form-element-2">
#       <label for="username">
#        Username
#        <span class="wppb-required" title="This field is required">
#         *
#        </span>
#       </label>
#       <input class="text-input default_field_username " id="username" maxlength="70" name="username" required="" type="text" value=""/>
#       <span class="wppb-description-delimiter">
#        Usernames cannot be changed.
#       </span>
#      </li>
#      <li class="wppb-form-field wppb-default-password" id="wppb-form-element-15">
#       <label for="passw1">
#        Password
#        <span class="wppb-required" title="This field is required">
#         *
#        </span>
#       </label>
#       <input autocomplete="off" class="text-input " id="passw1" maxlength="70" name="passw1" required="" type="password" value=""/>
#       <span class="wppb-description-delimiter">
#        Type your password. Minimum length of 5 characters.
#        <br>
#         The password must have a minimum strength of Very Weak.
#        </br>
#       </span>
#       <span id="pass-strength-result">
#        Strength indicator
#       </span>
#       <input id="wppb_password_strength" name="wppb_password_strength" type="hidden" value=""/>
#      </li>
#      <li class="wppb-form-field wppb-default-repeat-password" id="wppb-form-element-16">
#       <label for="passw2">
#        Repeat Password
#        <span class="wppb-required" title="This field is required">
#         *
#        </span>
#       </label>
#       <input autocomplete="off" class="text-input " id="passw2" maxlength="70" name="passw2" required="" type="password" value=""/>
#       <span class="wppb-description-delimiter">
#        Type your password again.
#       </span>
#      </li>
#      <li class="wppb-form-field wppb-mailchimp-subscribe" id="wppb-form-element-33">
#       <label for="custom_field_mailchimp_subscribe_33">
#        <input checked="checked" class="extra_field_mailchimp" id="custom_field_mailchimp_subscribe_33" name="custom_field_mailchimp_subscribe_33" type="checkbox" value="528b1d47d5"/>
#        Subscribe to Newsletter
#       </label>
#      </li>
#     </ul>
#     <ul>
#      <li class="wppb-form-field wppb-send-credentials-checkbox">
#       <label for="send_credentials_via_email">
#        <input id="send_credentials_via_email" name="send_credentials_via_email" type="checkbox" value="sending"/>
#        Send these credentials via email.
#       </label>
#      </li>
#     </ul>
#     <p class="form-submit">
#      <input class="submit button" id="register" name="register" type="submit" value="Register"/>
#      <input id="action" name="action" type="hidden" value="register"/>
#      <input id="form_name" name="form_name" type="hidden" value="lightbox"/>
#      <input name="wppb_referer_url" type="hidden" value=""/>
#     </p>
#     <!-- .form-submit -->
#     <input id="register_lightbox_nonce_field" name="register_lightbox_nonce_field" type="hidden" value="7fb2e145dd"/>
#     <input name="_wp_http_referer" type="hidden" value="/shop/"/>
#    </form>
#   </div>
#   <script>
#    jQuery( '.open-register-lightbox' ).magnificPopup({
# 	type: 'inline',
# 	midClick: true,
# 	closeBtnInside: true
# });
# jQuery( '.fusion-menu-login-box-register' ).magnificPopup({
# 	items: {
# 		type: 'inline',
# 		src: '#register-lightbox'
# 	},
# 	closeBtnInside: true,
# 	midClick: true
# });
#   </script>
#  </body>
# </html>
# <!-- This website is like a Rocket, isn't it? Performance optimized by WP Rocket. Learn more: https://wp-rocket.me -->

# %% [markdown]
# Now let's take a look through the structure and find the data.

# %%
# I wouldn't expect my data to be here, but there is some metadata if we want it.
soup.head
# Out:
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Products – The Scotch Malt Whisky Society Australia</title>
# <link href="//chimpstatic.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="https://www.smws.com.au/feed/" rel="alternate" title="The Scotch Malt Whisky Society Australia » Feed" type="application/rss+xml"/>
# <link href="https://www.smws.com.au/comments/feed/" rel="alternate" title="The Scotch Malt Whisky Society Australia » Comments Feed" type="application/rss+xml"/>
# <link href="https://www.smws.com.au/events/?ical=1" rel="alternate" title="The Scotch Malt Whisky Society Australia » iCal Feed" type="text/calendar"/>
# <link href="https://www.smws.com.au/shop/feed/" rel="alternate" title="The Scotch Malt Whisky Society Australia » Products Feed" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/11\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/www.smws.com.au\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.9.9"}};
# 			!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55358,56760,9792,65039],[55358,56760,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="http://www.smws.com.au/wp-includes/css/dashicons.min.css?ver=4.9.9" id="dashicons-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="dashicons-inline-css" type="text/css">
# [data-font="Dashicons"]:before {font-family: 'Dashicons' !important;content: attr(data-icon) !important;speak: none !important;font-weight: normal !important;font-variant: normal !important;text-transform: none !important;line-height: 1 !important;font-style: normal !important;-webkit-font-smoothing: antialiased !important;-moz-osx-font-smoothing: grayscale !important;}
# </style>
# <link href="http://www.smws.com.au/wp-content/plugins/event-tickets-plus/src/resources/css/tickets.min.css?ver=4.8.3" id="event-tickets-plus-tickets-css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.smws.com.au/wp-content/plugins/pb-add-on-mailchimp-integration/assets/css/style-front-end.css?ver=4.9.9" id="wppb-mailchimp-integration-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="woocommerce-inline-inline-css" type="text/css">
# .woocommerce form .form-row .required { visibility: visible; }
# </style>
# <link href="http://www.smws.com.au/wp-content/plugins/fusion-core/css/style.min.css?ver=4.9.9" id="fusion-core-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.smws.com.au/wp-content/plugins/yith-woocommerce-badge-management-premium/assets/css/frontend.css?ver=1.3.17" id="yith_wcbm_badge_style-css" media="all" rel="stylesheet" type="text/css"/>
# <style id="yith_wcbm_badge_style-inline-css" type="text/css">
# .yith-wcbm-badge-29614{ top: -5px;bottom: auto;left: -9px;right: auto; opacity: 1; }.yith-wcbm-badge-29614 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-22304{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-22304 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-21537{ top: 0px;bottom: auto;left: 19px;right: auto; opacity: 1; }.yith-wcbm-badge-21537 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-17855{ top: auto;bottom: 0px;left: calc(50% - 55px);right: auto; opacity: 1; }.yith-wcbm-badge-17855 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-29019{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-29019 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-32212{ top: 1px;bottom: auto;left: 2px;right: auto; opacity: 1; }.yith-wcbm-badge-32212 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-21874{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-21874 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-4659{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 0.92; }.yith-wcbm-badge-4659 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-5977{ top: -9px;bottom: auto;left: -3px;right: auto; opacity: 1; }.yith-wcbm-badge-5977 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-29020{ top: -15px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-29020 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-21536{ top: 0px;bottom: auto;left: auto;right: 0px; opacity: 1; }.yith-wcbm-badge-21536 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-21470{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-21470 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-18607{ top: 0px;bottom: auto;left: 0px;right: auto; opacity: 1; }.yith-wcbm-badge-18607 .yith-wcbm-badge__wrap{ -ms-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); -webkit-transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); transform: rotateX(0deg) rotateY(0deg) rotateZ(0deg); }.yith-wcbm-badge-6441{ top: 0 ...
# </style>
# <link href="//fonts.googleapis.com/css?family=Open+Sans%3A400%2C600%2C700%2C800%2C300&amp;ver=4.9.9" id="googleFontsOpenSans-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.smws.com.au/wp-content/plugins/woocommerce-memberships/assets/css/frontend/wc-memberships-frontend.min.css?ver=1.12.2" id="wc-memberships-frontend-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.smws.com.au/wp-content/themes/Avada/assets/css/style.min.css?ver=5.7.2" id="avada-stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.smws.com.au/wp-content/themes/Avada-Child-Theme/style.css?ver=4.9.9" id="child-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.smws.com.au/wp-content/themes/Avada-Child-Theme/css/magnific-popup.css?ver=4.9.9" id="magnific-popup-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.smws.com.au/wp-content/themes/Avada/includes/lib/assets/fonts/fontawesome/font-awesome.min.css?ver=5.7.2" id="fontawesome-css" media="all" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 9]>
# <link rel='stylesheet' id='avada-IE-fontawesome-css'  href='http://www.smws.com.au/wp-content/themes/Avada/includes/lib/assets/fonts/fontawesome/font-awesome.min.css?ver=5.7.2' type='text/css' media='all' />
# <![endif]-->
# <!--[if IE]>
# <link rel='stylesheet' id='avada-IE-css'  href='http://www.smws.com.au/wp-content/themes/Avada/assets/css/ie.min.css?ver=5.7.2' type='text/css' media='all' />
# <![endif]-->
# <link href="http://www.smws.com.au/wp-content/plugins/fusion-builder/css/fusion-shortcodes.min.css?ver=1.7.2" id="fusion-builder-shortcodes-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.smws.com.au/wp-content/plugins/fusion-builder/assets/css/animations.min.css?ver=1.7.2" id="fusion-builder-animations-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.smws.com.au/wp-content/plugins/fusion-builder/assets/css/ilightbox.min.css?ver=1.7.2" id="fusion-builder-ilightbox-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://www.smws.com.au/wp-content/plugins/profile-builder-pro/assets/css/style-front-end.css?ver=2.9.2" id="wppb_stylesheet-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="http://www.smws.com.au/wp-includes/js/jquery/jquery.js?ver=1.12.4" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-includes/js/jquery/jquery-migrate.min.js?ver=1.4.1" type="text/javascript"></script>
# <link href="https://www.smws.com.au/wp-json/" rel="https://api.w.org/"/>
# <link href="https://www.smws.com.au/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="http://www.smws.com.au/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="v1" name="et-api-version"><meta content="https://www.smws.com.au" name="et-api-origin"><link href="https://www.smws.com.au/wp-json/tribe/tickets/v1/" rel="https://theeventscalendar.com/"/><meta content="v1" name="tec-api-version"><meta content="https://www.smws.com.au" name="tec-api-origin"><link href="https://www.smws.com.au/wp-json/tribe/events/v1/" rel="https://theeventscalendar.com/"/><meta content="always" name="referrer"/> <noscript><style>.woocommerce-product-gallery{ opacity: 1 !important; }</style></noscript>
# <style id="fusion-stylesheet-inline-css" type="text/css">@font-face {
#   font-family: 'Roboto';
#   font-style: italic;
#   font-weight: 400;
#   src: local('Roboto Italic'), local('Roboto-Italic'), url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xEIzc.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: italic;
#   font-weight: 700;
#   src: local('Roboto Bold Italic'), local('Roboto-BoldItalic'), url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51TzBic2CsE.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 400;
#   src: local('Roboto'), local('Roboto-Regular'), url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu7mxP.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 500;
#   src: local('Roboto Medium'), local('Roboto-Medium'), url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fCBc9.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Roboto';
#   font-style: normal;
#   font-weight: 700;
#   src: local('Roboto Bold'), local('Roboto-Bold'), url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfCBc9.ttf) format('truetype');
# }
# @font-face {
#   font-family: 'Rufina';
#   font-style: normal;
#   font-weight: 400;
#   src: local('Rufina'), local('Rufina-Regular'), url(//fonts.gstatic.com/s/rufina/v5/Yq6V-LyURyLy-aKCpB5g.ttf) format('truetype');
# }
# /********* Compiled CSS - Do not edit *********/@font-face{font-family:;src:;font-weight: normal;font-style: normal;}.group{zoom:1}.group:after,.group:before{content:" ";display:table}.group:after{clear:both}.woocommerce input[type=number]{-moz-appearance:textfield}.woocommerce input[type=number].qty::-webkit-inner-spin-button,.woocommerce input[type=number].qty::-webkit-outer-spin-button{-webkit-appearance:none;margin:0}.woocommerce-info,.woocommerce-message{margin-bottom:30px;padding:20px 0 20px 16px;border:none;text-align:left}.woocommerce-info:before,.woocommerce-message:before{position:absolute;margin-left:-16px;font-family:IcoMoon;content:'\f05d'}.woocommerce-info .wc-forward,.woocommerce-message .wc-forward{float:right;text-shadow:none}.woocommerce-info .wc-forward:before,.woocommerce-message .wc-forward:before{font-family:IcoMoon;content:'\f07a';margin-right:6px;color:inherit}.woocommerce-error{list-style:none;padding:0}.woocommerce-error li{margin-bottom:15px;padding:8px;position:relative;text-align:center}.woocommerce .avada-order-details .order-again .button,.woocommerce .login .button,.woocommerce .lost_reset_password input[type=submit],.woocommerce .register .button,.woocommerce .shipping-calculator-form .button,.woocommerce button.button,.woocommerce button.fusion-button{text-transform:uppercase;text-align:center;margin:0;cursor:pointer}.woocommerce .lost_reset_password input[type=submit]{border:0}.woocommerce .button{cursor:pointer}.woocommerce .single_add_to_cart_button,.woocommerce button.button{margin-top:-1px}.woocommerce .avada-shipping-calculator-form .button,.woocommerce .shipping-calculator-form .button{float:right;margin-top:0}.woocommerce-checkout .woocommerce .woocommerce-form-login{margin-bottom:20px}.woocommerce .login .form-row{text-align:initial;margin:0 20px 0 15px;float:right}.woocommerce .login .form-row.form-row-first,.woocommerce .login .form-row.form-row-last{margin:0 0 20px;float:none}.woocommerce .login .button{margin-left:15px}.woocommerce .login .inline{float:left;margin-top:5px}.woocommerce .login .lost_password{float:right;margin-top:5px}.woocommerce #customer_login .login .form-row{display:inline-block;float:none;margin:0 18px 0 0;text-align:initial}.woocommerce #customer_login .login .form-row.form-row-wide{display:block;margin:0 0 20px}.woocommerce #customer_login .login .button{margin-left:0}.woocommerce #customer_login .login .inline{display:inline-block;vertical-align:middle;float:none;margin-top:0;margin-left:15px;line-height:1}.woocommerce #customer_login .login .inline .woocommerce-Input,.woocommerce #customer_login .login .inline input{vertical-align:middle;margin:0 3px}.woocommerce #customer_login .login .lost_password{display:inline-block;vertical-align:middle;float:none;margin:0}.woocommerce #customer_login .register .form-row:last-child{margin-bottom:0}.woocommerce .checkout_coupon{margin-bottom:40px;display:-webkit-flex!important;display:-ms-flexbox!important;display:flex!important;-webkit-align-items:center;-ms-flex-align:center;align-items:center;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between}.woocommerce .checkout_coupon .promo-code-heading{margin:0;padding:0;border:none}.woocommerce .checkout_coupon .coupon-contents{display:-webkit-flex!important;display:-ms-flexbox!important;display:flex!important;-webkit-align-items:center;-ms-flex-align:center;align-items:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-order:4;-ms-flex-order:4;order:4;margin:0 -7.5px}.woocommerce .checkout_coupon .coupon-input{width:240px;margin:0;padding:5px 7.5px}.woocommerce .checkout_coupon .coupon-input .input-text{margin:0;padding:8px 15px}.woocommerce .checkout_coupon .coupon-button{margin:0;padding:5px 7.5px}.woocommerce-ordering{display:none}.woocommerce-invalid:after{display:inline-block;margin-top:7px;color:red}.woocommerce .woocommerce-container{ ...
#     height: 40px;
# }
# .shop_table td {
#     padding: 10px 0 !important;
# }
# .shop_table thead tr th {
#     border-top: 0 none !important;
#     font-size: 13px;
#     font-weight: bold;
#     padding-bottom: 12px;
# }
# .shop_table tbody tr:last-child {
#     border-bottom: 1px solid #ddd !important;
# }
# .shop_table .product-quantity {
#     text-align: center;
#     width: 15%;
# }
# .shop_table .product-name {
#     width: 45%;
# }
# .cart_totals table th {
#     padding-bottom: 20px;
#     width: 25%;
# }
# .woocommerce-cart .cart_totals .shop_table .cart-subtotal {
#     border-bottom: 0 none;
#     display: none !important;
# }
# .woocommerce-cart .cart_totals .shop_table .recurring-totals {
#     border-bottom: 0 none;
#     display: none !important;
# }
# .checkout .shop_table tfoot th {
#     padding: 15px;
#     text-align: right;
#     width: 70% !important;
# }
# .checkout .shop_table tfoot td {
#     padding: 15px;
#     text-align: right;
# }
# .checkout .shop_table tfoot tr {
#     border-bottom: 1px solid #ddd;
# }
# .payment_methods li img {
#     clear: both;
#     float: left;
# }
# form.cart {
#     margin-bottom: 40px;
#     margin-top: 5px !important;
# }
# .checkout .payment_methods .payment_box {
#     clear: both;
#     height: 220px;
#     margin-top: 10px;
#     padding: 20px;
# }
# .coupon .input-text {
#     float: left;
#     margin-left: 0;
#     margin-right: 0;
#     margin-top: 15px;
#     padding-left: 15px;
#     padding-right: 15px;
#     width: 75%;
# }
# .woocommerce .cc-checkout {
#     float: left;
#     margin-right: 30px;
# }
# .order_details {
#     float: left;
#     margin-right: 30px;
# }
# .checkout .cart-subtotal {
#     display: none;
# }
# .checkout .recurring-totals {
#     display: none;
# }
# .gift-certificate {
#     float: left;
#     margin: 0;
#     padding-left: 25px;
#     padding-right: 25px;
#     width: 100%;
# }
# .tribe-events-style-full table.tribe-events-tickets td {
#     border-bottom: 0 none;
# }
# table.tribe-events-tickets td {
#     border-top: 1px solid #ddd;
#     float: left;
#     padding: 8px 10px 8px 0;
#     vertical-align: middle;
#     width: 100%;
# }
# .tribe-tickets-remaining {
#     vertical-align: middle;
#     float: right;
# }
# .tribe-tickets-attendees-list-optout label {
#     font-size: 12px;
#     margin-left: 5px;
# }
# .cart_totals table {
#     margin-bottom: 20px;
#     text-align: left;
#     width: 100%;
# }
# .shop_table {
#     margin-bottom: 30px;
#     text-align: left;
#     width: 100%;
# }
# h2.tribe-events-tickets-title {
#     background-color: #aace4e;
#     padding: 9px 15px;
# }
# h2.tribe-events-tickets-title {
#     color: #333333;
# }
# h2.tribe-events-tickets-title {
#     font-size: 17px;
# }
# form.checkout label {
#     display: inline-block;
#     margin-bottom: 2px;
#     padding-right: 10px;
# }
# .quantity .minus, .quantity .plus, .quantity .qty {
#     font-size: 18px;
#     height: 40px;
#     line-height: 21px;
#     width: 40px;
# }
# .coupon .input-text {
#     float: left;
#     height: 59px;
#     margin-left: 0;
#     margin-right: 0;
#     margin-top: 1px;
#     padding-left: 15px;
#     padding-right: 15px;
#     width: 75%;
# }
# .fusion-page-title-bar h1 {
#     font-size: 18px;
# }
# #wrapper #main .fusion-portfolio-content > h2.entry-title, #wrapper #main .fusion-post-content > .blog-shortcode-post-title, #wrapper #main .fusion-post-content > h2.entry-title, #wrapper #main .post > h2.entry-title, #wrapper .fusion-events-shortcode .fusion-events-meta h2, .single-product .product .product_title {
#     font-size: 28px;
# }
# .fusion-woo-product-design-clean .products .product-title {
#     font-size: 22px;
#     font-style: normal;
# }
# .woocommerce_account_subscriptions {
#     display: none;
# }
# .woocommerce span.onsale.wc-memberships-member-discount {
#     display: none !important;
# }@media only screen and (max-width: 644px){.fusion-blog-layout-grid-6 .fusion-post-grid,.fusion-grid-6 .fusion-grid-column,.fusion-portfolio-six .fusion-portfolio-post{width:100%!important}.fusion-blog-layout-grid-6 .fusion-post-grid.fusion-element-landscape .fusion-masonry-element-container,.fusion-grid-6 .fusion-grid-column.fusion-element-landscape .fusion-masonry-element-container,.fusion-portfolio-six .fusion-portfolio-post.fusion-element-landscape .fusion-masonry-element-container{padding-top:65%!important}.fusion-blog-layout-grid-6 .fusion-post-grid.fusion-element-grid .fusion-masonry-element-container,.fusion-grid-6 .fusion-grid-column.fusion-element-grid .fusion-masonry-element-container,.fusion-portfolio-six .fusion-portfolio-post.fusion-element-grid .fusion-masonry-element-container{padding-top:100%!important}}@media only screen and (max-width: 735px){.fusion-blog-layout-grid .fusion-post-grid,.fusion-grid-column,.fusion-portfolio-post{width:100%!important}.fusion-blog-layout-grid .fusion-post-grid.fusion-element-landscape .fusion-masonry-element-container,.fusion-grid-column.fusion-element-landscape .fusion-masonry-element-container,.fusion-portfolio-post.fusion-element-landscape .fusion-masonry-element-container{padding-top:65%!important}.fusion-blog-layout-grid .fusion-post-grid.fusion-element-grid .fusion-masonry-element-container,.fusion-grid-column.fusion-element-grid .fusion-masonry-element-container,.fusion-portfolio-post.fusion-element-grid .fusion-masonry-element-container{padding-top:100%!important}.fusion-portfolio-grid:not(.fusion-portfolio-text) .fusion-portfolio-post .fusion-image-wrapper{display:block;text-align:center}.fusion-blog-layout-grid-6 .fusion-post-grid,.fusion-grid-6 .fusion-grid-column,.fusion-portfolio-six .fusion-portfolio-post{width:50%!important}.fusion-blog-layout-grid-6 .fusion-post-grid.fusion-element-landscape,.fusion-grid-6 .fusion-grid-column.fusion-element-landscape,.fusion-portfolio-six .fusion-portfolio-post.fusion-element-landscape{width:100%!important}}@media only screen and (min-width: 735px) and (max-width: 826px){.fusion-blog-layout-grid-6 .fusion-post-grid,.fusion-grid-6 .fusion-grid-column,.fusion-portfolio-six .fusion-portfolio-post{width:33.3333333333%!important}.fusion-blog-layout-grid-6 .fusion-post-grid.fusion-element-landscape,.fusion-grid-6 .fusion-grid-column.fusion-element-landscape,.fusion-portfolio-six .fusion-portfolio-post.fusion-element-landscape{width:66.6666666666%!important}.fusion-blog-layout-grid-3 .fusion-post-grid,.fusion-blog-layout-grid-4 .fusion-post-grid,.fusion-blog-layout-grid-5 .fusion-post-grid,.fusion-grid-3 .fusion-grid-column,.fusion-grid-4 .fusion-grid-column,.fusion-grid-5 .fusion-grid-column,.fusion-portfolio-five .fusion-portfolio-post,.fusion-portfolio-four .fusion-portfolio-post,.fusion-portfolio-masonry .fusion-portfolio-post,.fusion-portfolio-three .fusion-portfolio-post{width:50%!important}.fusion-blog-layout-grid-3 .fusion-post-grid.fusion-element-landscape,.fusion-blog-layout-grid-4 .fusion-post-grid.fusion-element-landscape,.fusion-blog-layout-grid-5 .fusion-post-grid.fusion-element-landscape,.fusion-grid-3 .fusion-grid-column.fusion-element-landscape,.fusion-grid-4 .fusion-grid-column.fusion-element-landscape,.fusion-grid-5 .fusion-grid-column.fusion-element-landscape,.fusion-portfolio-five .fusion-portfolio-post.fusion-element-landscape,.fusion-portfolio-four .fusion-portfolio-post.fusion-element-landscape,.fusion-portfolio-masonry .fusion-portfolio-post.fusion-element-landscape,.fusion-portfolio-three .fusion-portfolio-post.fusion-element-landscape{width:100%!important}}@media only screen and (min-width: 826px) and (max-width: 917px){.fusion-blog-layout-grid-6 .fusion-post-grid,.fusion-grid-6 .fusion-grid-column,.fusion-portfolio-six .fusion-portfolio-post{width:25%!important}.fusion-blog-layout-grid-6 .fusion-post-grid.fusion-element-landscape,.fusion-grid-6 .fusion-grid-column.fusion-element-landscape,.fusion-portfolio-si ...
# <script type="text/javascript">
# 			var gaProperty = 'UA-47772714-1';
# 			var disableStr = 'ga-disable-' + gaProperty;
# 			if ( document.cookie.indexOf( disableStr + '=true' ) > -1 ) {
# 				window[disableStr] = true;
# 			}
# 			function gaOptout() {
# 				document.cookie = disableStr + '=true; expires=Thu, 31 Dec 2099 23:59:59 UTC; path=/';
# 				window[disableStr] = true;
# 			}
# 		</script>
# <script type="text/javascript">(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 		(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 		m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 		})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga( 'create', 'UA-47772714-1', 'auto' );ga( 'set', 'anonymizeIp', true );
# 		ga( 'set', 'dimension1', 'no' );
# ga( 'require', 'ecommerce', 'ecommerce.js');</script>
# <!-- /WooCommerce Google Analytics Integration -->
# <script type="text/javascript">
# 		var doc = document.documentElement;
# 		doc.setAttribute('data-useragent', navigator.userAgent);
# 	</script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-47772714-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-119539316-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-119539316-1');
# </script><script>(function(w,d,t,r,u){var f,n,i;w[u]=w[u]||[],f=function(){var o={ti:"25019964"};o.q=w[u],w[u]=new UET(o),w[u].push("pageLoad")},n=d.createElement(t),n.src=r,n.async=1,n.onload=n.onreadystatechange=function(){var s=this.readyState;s&&s!=="loaded"&&s!=="complete"||(f(),n.onload=n.onreadystatechange=null)},i=d.getElementsByTagName(t)[0],i.parentNode.insertBefore(n,i)})(window,document,"script","//bat.bing.com/bat.js","uetq");</script></meta></meta></meta></meta></head>

# %%
soup.body
# Out:
# <body class="archive post-type-archive post-type-archive-product woocommerce woocommerce-page woocommerce-no-js tribe-no-js yith-wcbm-theme-avada fusion-image-hovers fusion-body ltr fusion-sticky-header no-tablet-sticky-header no-mobile-sticky-header no-mobile-slidingbar fusion-disable-outline layout-wide-mode has-sidebar fusion-top-header menu-text-align-left fusion-woo-product-design-clean mobile-menu-design-classic fusion-show-pagination-text fusion-header-layout-v3 avada-responsive avada-footer-fx-bg-parallax fusion-search-form-classic fusion-avatar-square">
# <a class="skip-link screen-reader-text" href="#content">Skip to content</a>
# <div class="" id="wrapper">
# <div id="home" style="position:relative;top:-1px;"></div>
# <header class="fusion-header-wrapper fusion-header-shadow">
# <div class="fusion-header-v3 fusion-logo-left fusion-sticky-menu- fusion-sticky-logo- fusion-mobile-logo-1 fusion-mobile-menu-design-classic">
# <div class="fusion-secondary-header">
# <div class="fusion-row">
# <div class="fusion-alignleft">
# <div class="fusion-contact-info">Phone: 02 9974 3046<span class="fusion-header-separator">|</span><a href="/cdn-cgi/l/email-protection#7e585d4f4e4b45585d4f4f4e4518585d4f4f4f45585d484a450d13585d4f4f47450d50585d474745585d4f4f4f45585d4f4e4745501f0b">info@smws.com.au</a></div> </div>
# <div class="fusion-alignright">
# <div class="fusion-social-links-header"><div class="fusion-social-networks"><div class="fusion-social-networks-wrapper"><a class="fusion-social-network-icon fusion-tooltip fusion-facebook fusion-icon-facebook" data-placement="bottom" data-title="Facebook" data-toggle="tooltip" href="https://www.facebook.com/Australiansmws" rel="noopener noreferrer" style="color:#ffffff;" target="_blank" title="Facebook"><span class="screen-reader-text">Facebook</span></a><a class="fusion-social-network-icon fusion-tooltip fusion-instagram fusion-icon-instagram" data-placement="bottom" data-title="Instagram" data-toggle="tooltip" href="https://www.instagram.com/smws_aus/" rel="noopener noreferrer" style="color:#ffffff;" target="_blank" title="Instagram"><span class="screen-reader-text">Instagram</span></a><a class="fusion-social-network-icon fusion-tooltip fusion-twitter fusion-icon-twitter" data-placement="bottom" data-title="Twitter" data-toggle="tooltip" href="https://twitter.com/SMWS_Australia" rel="noopener noreferrer" style="color:#ffffff;" target="_blank" title="Twitter"><span class="screen-reader-text">Twitter</span></a><a class="fusion-social-network-icon fusion-tooltip fusion-linkedin fusion-icon-linkedin" data-placement="bottom" data-title="LinkedIn" data-toggle="tooltip" href="https://www.linkedin.com/company/scotch-malt-whisky-society-australia" rel="noopener noreferrer" style="color:#ffffff;" target="_blank" title="LinkedIn"><span class="screen-reader-text">LinkedIn</span></a></div></div></div> </div>
# </div>
# </div>
# <div class="fusion-header-sticky-height"></div>
# <div class="fusion-header">
# <div class="fusion-row">
# <div class="fusion-logo" data-margin-bottom="15px" data-margin-left="0px" data-margin-right="0px" data-margin-top="15px">
# <a class="fusion-logo-link" href="https://www.smws.com.au/">
# <!-- standard logo -->
# <img alt="The Scotch Malt Whisky Society Australia Logo" class="fusion-standard-logo" height="" retina_logo_url="" src="http://www.smws.com.au/wp-content/uploads/2017/10/SMWS-Off-Pack-Logo-Landscape-white-1.png" srcset="http://www.smws.com.au/wp-content/uploads/2017/10/SMWS-Off-Pack-Logo-Landscape-white-1.png 1x" width=""/>
# <!-- mobile logo -->
# <img alt="The Scotch Malt Whisky Society Australia Logo" class="fusion-mobile-logo" height="" retina_logo_url="" src="http://www.smws.com.au/wp-content/uploads/2017/10/amsllSMWS-Off-Pack-Logo-Portrait-white-copy.png" srcset="http://www.smws.com.au/wp-content/uploads/2017/10/amsllSMWS-Off-Pack-Logo-Portrait-white-copy.png 1x" width=""/>
# </a>
# </div> <nav aria-label="Main Menu" class="fusion-main-menu"><ul class="fusion-menu" id="menu-main-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home menu-item-2458" data-item-id="2458" id="menu-item-2458"><a class="fusion-bar-highlight" href="https://www.smws.com.au/" role="menuitem"><span class="menu-text">Home</span></a></li><li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item current_page_item menu-item-2459" data-item-id="2459" id="menu-item-2459"><a class="fusion-bar-highlight" href="https://www.smws.com.au/shop/" role="menuitem"><span class="menu-text">Shop</span></a></li><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-2462 fusion-megamenu-menu" data-item-id="2462" id="menu-item-2462"><a class="fusion-bar-highlight" href="#" role="menuitem"><span class="menu-text">Society</span> <span class="fusion-caret"><i class="fusion-dropdown-indicator"></i></span></a><div class="fusion-megamenu-wrapper fusion-columns-4 columns-per-row-4 columns-4 col-span-12 fusion-megamenu-fullwidth" data-maxwidth="1100"><div class="row"><div class="fusion-megamenu-holder" data-width="1100" style="width:1100px;"><ul class="fusion-megamenu " role="menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-2463 fusion-megamenu-submenu fusion-megamenu-columns-4 col-lg-3 col-md-3 col-sm-3" id="menu-item-2463"><div class="fusion-megamenu-title"><span class="fusion-megamenu-icon"><i class="glyphicon fa fa-key"></i></span>MEMBERSHIP INFO</div><ul class="sub-menu" role="menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2475" id="menu-item-2475"><a class="fusion-bar-highlight" href="https://www.smws.com.au/membership/" role="menuitem"><span><span class="fusion-megamenu-bullet"></span>Membership Information</span></a></li><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2484" id="menu-item-2484"><a class="fusion-bar-highlight" href="https://www.smws.com.au/product/smws-annual-membership-subscription/" role="menuitem"><span><span class="fusion-megamenu-bullet"></span>Purchase Membership</span></a></li><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2482" id="menu-item-2482"><a class="fusion-bar-highlight" href="https://www.smws.com.au/product/smws-gift-membership/" role="menuitem"><span><span class="fusion-megamenu-bullet"></span>Purchase Gift Membership</span></a></li><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2472" id="menu-item-2472"><a class="fusion-bar-highlight" href="https://www.smws.com.au/society/" role="menuitem"><span><span class="fusion-megamenu-bullet"></span>About the Society</span></a></li></ul></li><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-2464 fusion-megamenu-submenu fusion-megamenu-columns-4 col-lg-3 col-md-3 col-sm-3" id="menu-item-2464"><div class="fusion-megamenu-title"><span class="fusion-megamenu-icon"><i class="glyphicon fa fa-comments"></i></span>NEWS &amp; INFO</div><ul class="sub-menu" role="menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2483" id="menu-item-2483"><a class="fusion-bar-highlight" href="https://www.smws.com.au/news/" role="menuitem"><span><span class="fusion-megamenu-bullet"></span>Whiskywise</span></a></li><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2469" id="menu-item-2469"><a class="fusion-bar-highlight" href="https://www.smws.com.au/outturn-magazine-2/" role="menuitem"><span><span class="fusion-megamenu-bullet"></span>Outturn Magazine</span></a></li><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2468" id="menu-item-2468"><a class="fusion-bar-highlight" href="https://www.smws.com.au/unfiltered-magazine/" role="menuitem"><span><span class="fusion-megamenu-bullet"></spa ...
# <nav aria-label="Main Menu Mobile" class="fusion-mobile-nav-holder fusion-mobile-menu-text-align-center"></nav>
# </div>
# </div>
# </div>
# <div class="fusion-clearfix"></div>
# </header>
# <div id="sliders-container">
# </div>
# <div class="fusion-page-title-bar fusion-page-title-bar-none fusion-page-title-bar-left">
# <div class="fusion-page-title-row">
# <div class="fusion-page-title-wrapper">
# <div class="fusion-page-title-captions">
# <h1 class="entry-title">Shop</h1>
# </div>
# <div class="fusion-page-title-secondary">
# <div class="fusion-breadcrumbs"><span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><a href="https://www.smws.com.au" itemprop="url"><span itemprop="title">Home</span></a></span><span class="fusion-breadcrumb-sep">/</span><span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb"><span class="breadcrumb-leaf" itemprop="title">Shop</span></span></div> </div>
# </div>
# </div>
# </div>
# <main class="clearfix " id="main" role="main" style="">
# <div class="fusion-row" style="">
# <div class="woocommerce-container">
# <section class="" id="content" style="float: right;">
# <header class="woocommerce-products-header">
# </header>
# <div class="woocommerce-notices-wrapper"></div>
# <div class="catalog-ordering fusion-clearfix">
# <div class="orderby-order-container">
# <ul class="orderby order-dropdown">
# <li>
# <span class="current-li">
# <span class="current-li-content">
# <a aria-haspopup="true">Sort by <strong>Date</strong></a>
# </span>
# </span>
# <ul>
# <li class="">
# <a href="?product_orderby=name">Sort by <strong>Name</strong></a>
# </li>
# <li class="">
# <a href="?product_orderby=price">Sort by <strong>Price</strong></a>
# </li>
# <li class="current">
# <a href="?product_orderby=date">Sort by <strong>Date</strong></a>
# </li>
# <li class="">
# <a href="?product_orderby=popularity">Sort by <strong>Popularity</strong></a>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="order">
# <li class="desc"><a aria-haspopup="true" aria-label="Ascending order" href="?product_order=asc"><i class="fusion-icon-arrow-down2 icomoon-up"></i></a></li>
# </ul>
# </div>
# <ul class="sort-count order-dropdown">
# <li>
# <span class="current-li"><a aria-haspopup="true">Show <strong>20 Products</strong></a></span>
# <ul>
# <li class="current">
# <a href="?product_count=20">Show <strong>20 Products</strong></a>
# </li>
# <li class="">
# <a href="?product_count=40">Show <strong>40 Products</strong></a>
# </li>
# <li class="">
# <a href="?product_count=60">Show <strong>60 Products</strong></a>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="fusion-grid-list-view">
# <li class="fusion-grid-view-li active-view">
# <a aria-haspopup="true" aria-label="View as grid" class="fusion-grid-view" href="?product_view=grid"><i class="fusion-icon-grid icomoon-grid"></i></a>
# </li>
# <li class="fusion-list-view-li">
# <a aria-haspopup="true" aria-label="View as list" class="fusion-list-view" href="?product_view=list"><i class="fusion-icon-list icomoon-list"></i></a>
# </li>
# </ul>
# </div>
# <ul class="products clearfix products-4">
# <li class="post-32199 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-lightly-peated membership-content purchase-restricted product-grid-view first instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <div class="container-image-and-badge "><img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/4.238-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/4.238-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/4.238-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/4.238.png 400w" width="200"/> <div class="yith-wcbm-badge yith-wcbm-badge-image yith-wcbm-badge-32212" data-position='{"top":"1","bottom":"auto","left":"2","right":"auto"}'>
# <div class="yith-wcbm-badge__wrap">
# <img alt="" src="//www.smws.com.au/wp-content/uploads/2018/12/Islands-SILVER-Logo_IBC18-2_micro.png"/> </div><!--yith-wcbm-badge__wrap-->
# </div><!--yith-wcbm-badge-->
# </div><!--container-image-and-badge-->
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/4-238-surrender-your-soul/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="4.238 Surrender your soul" class="fusion-link-wrapper" href="https://www.smws.com.au/product/4-238-surrender-your-soul/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/4-238-surrender-your-soul/">
# 		4.238 Surrender your soul	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>231.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-32045 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-deep-rich-dried-fruits membership-content purchase-restricted product-grid-view instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/12/68.18-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/12/68.18-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/12/68.18-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/12/68.18.png 400w" width="200"/>
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/68-18-triple-berry-lamington-cake/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="68.18 Triple berry Lamington cake" class="fusion-link-wrapper" href="https://www.smws.com.au/product/68-18-triple-berry-lamington-cake/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/68-18-triple-berry-lamington-cake/">
# 		68.18 Triple berry Lamington cake	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>169.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31323 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-deep-rich-dried-fruits product_cat-juicy-oak-vanilla product_cat-single-cask-spirits membership-content purchase-restricted product-grid-view outofstock sold-individually taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <div class="container-image-and-badge "><img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="242" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/Around-the-world-200x242.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/Around-the-world-100x121.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/Around-the-world-200x242.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/Around-the-world-248x300.png 248w, https://www.smws.com.au/wp-content/uploads/2018/11/Around-the-world-400x484.png 400w, https://www.smws.com.au/wp-content/uploads/2018/11/Around-the-world.png 496w" width="200"/> <div class="yith-wcbm-badge yith-wcbm-badge-image yith-wcbm-badge-17855" data-position='{"top":"auto","bottom":0,"left":"calc(50% - 55px)","right":"auto"}'>
# <div class="yith-wcbm-badge__wrap">
# <img alt="" src="//www.smws.com.au/wp-content/uploads/2018/01/STAMP-dearly-departed-red-web.png"/> </div><!--yith-wcbm-badge__wrap-->
# </div><!--yith-wcbm-badge-->
# </div><!--container-image-and-badge-->
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/around-the-world-in-three-bottles/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="Around the world in three bottles" class="fusion-link-wrapper" href="https://www.smws.com.au/product/around-the-world-in-three-bottles/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/around-the-world-in-three-bottles/">
# 		Around the world in three bottles	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>615.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31313 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-single-cask-spirits membership-content purchase-restricted product-grid-view last instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/C6.1-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/C6.1-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/C6.1-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/C6.1.png 400w" width="200"/>
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/c6-1-wood-fired-wonder-juice-cognac/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="C6.1 Wood fired wonder juice (Cognac)" class="fusion-link-wrapper" href="https://www.smws.com.au/product/c6-1-wood-fired-wonder-juice-cognac/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/c6-1-wood-fired-wonder-juice-cognac/">
# 		C6.1 Wood fired wonder juice (Cognac)	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>280.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31315 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-peated membership-content purchase-restricted product-grid-view first instock sold-individually taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/Feis-Ille-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/Feis-Ille-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/Feis-Ille-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/Feis-Ille.png 400w" width="200"/>
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/feis-ile-twin-pack/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="Feis Ile Twin Pack" class="fusion-link-wrapper" href="https://www.smws.com.au/product/feis-ile-twin-pack/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/feis-ile-twin-pack/">
# 		Feis Ile Twin Pack	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>434.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31288 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-young-spritely membership-content purchase-restricted product-grid-view instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <div class="container-image-and-badge "><img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/93.92-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/93.92-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/93.92-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/93.92.png 400w" width="200"/> <div class="yith-wcbm-badge yith-wcbm-badge-image yith-wcbm-badge-29614" data-position='{"top":"-5","bottom":"auto","left":"-9","right":"auto"}'>
# <div class="yith-wcbm-badge__wrap">
# <img alt="" src="//www.smws.com.au/wp-content/uploads/2018/10/CharlieStamp.png"/> </div><!--yith-wcbm-badge__wrap-->
# </div><!--yith-wcbm-badge-->
# </div><!--container-image-and-badge-->
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/93-92-fruit-pie-in-a-cleaning-cupboard-2/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="93.92 Fruit pie in a cleaning cupboard" class="fusion-link-wrapper" href="https://www.smws.com.au/product/93-92-fruit-pie-in-a-cleaning-cupboard-2/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/93-92-fruit-pie-in-a-cleaning-cupboard-2/">
# 		93.92 Fruit pie in a cleaning cupboard	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>195.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31285 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-young-spritely membership-content purchase-restricted product-grid-view instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/123.26-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/123.26-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/123.26-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/123.26.png 400w" width="200"/>
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/123-26-blossom-falling-onto-sponge-cake/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="123.26 Blossom falling onto sponge cake" class="fusion-link-wrapper" href="https://www.smws.com.au/product/123-26-blossom-falling-onto-sponge-cake/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/123-26-blossom-falling-onto-sponge-cake/">
# 		123.26 Blossom falling onto sponge cake	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>167.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31312 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-single-cask-spirits membership-content purchase-restricted product-grid-view last instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/A4.1-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/A4.1-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/A4.1-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/A4.1.png 400w" width="200"/>
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/a4-1-elegant-and-inviting-armagnac/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="A4.1 Elegant and inviting (Armagnac)" class="fusion-link-wrapper" href="https://www.smws.com.au/product/a4-1-elegant-and-inviting-armagnac/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/a4-1-elegant-and-inviting-armagnac/">
# 		A4.1 Elegant and inviting (Armagnac)	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>180.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31284 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-young-spritely membership-content purchase-restricted product-grid-view first instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/12.16-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/12.16-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/12.16-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/12.16.png 400w" width="200"/>
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/12-16-moonlight-in-new-york/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="12.16 Moonlight in New York" class="fusion-link-wrapper" href="https://www.smws.com.au/product/12-16-moonlight-in-new-york/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/12-16-moonlight-in-new-york/">
# 		12.16 Moonlight in New York	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>170.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31283 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-young-spritely membership-content purchase-restricted product-grid-view instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/26.123-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/26.123-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/26.123-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/26.123.png 400w" width="200"/>
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/26-123-attractive-lively-fun/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="26.123 Attractive, lively fun" class="fusion-link-wrapper" href="https://www.smws.com.au/product/26-123-attractive-lively-fun/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/26-123-attractive-lively-fun/">
# 		26.123 Attractive, lively fun	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>165.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-29032 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-single-cask-spirits membership-content purchase-restricted product-grid-view outofstock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <div class="container-image-and-badge "><img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/B3.4-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/B3.4-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/B3.4-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/B3.4.png 400w" width="200"/> <div class="yith-wcbm-badge yith-wcbm-badge-image yith-wcbm-badge-17855" data-position='{"top":"auto","bottom":0,"left":"calc(50% - 55px)","right":"auto"}'>
# <div class="yith-wcbm-badge__wrap">
# <img alt="" src="//www.smws.com.au/wp-content/uploads/2018/01/STAMP-dearly-departed-red-web.png"/> </div><!--yith-wcbm-badge__wrap-->
# </div><!--yith-wcbm-badge-->
# </div><!--container-image-and-badge-->
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/b3-4-bucking-bronco/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="B3.4 Bucking bronco" class="fusion-link-wrapper" href="https://www.smws.com.au/product/b3-4-bucking-bronco/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/b3-4-bucking-bronco/">
# 		B3.4 Bucking bronco	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>190.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31300 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-sweet-fruity-mellow membership-content purchase-restricted product-grid-view last outofstock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <div class="container-image-and-badge "><img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/135.7-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/135.7-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/135.7-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/135.7.png 400w" width="200"/> <div class="yith-wcbm-badge yith-wcbm-badge-image yith-wcbm-badge-17855" data-position='{"top":"auto","bottom":0,"left":"calc(50% - 55px)","right":"auto"}'>
# <div class="yith-wcbm-badge__wrap">
# <img alt="" src="//www.smws.com.au/wp-content/uploads/2018/01/STAMP-dearly-departed-red-web.png"/> </div><!--yith-wcbm-badge__wrap-->
# </div><!--yith-wcbm-badge-->
# </div><!--container-image-and-badge-->
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/135-7-yoghurt-and-fruit-candies/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="135.7 Yoghurt and fruit candies" class="fusion-link-wrapper" href="https://www.smws.com.au/product/135-7-yoghurt-and-fruit-candies/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/135-7-yoghurt-and-fruit-candies/">
# 		135.7 Yoghurt and fruit candies	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>165.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31289 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-sweet-fruity-mellow membership-content purchase-restricted product-grid-view first instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/112.29-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/112.29-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/112.29-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/112.29.png 400w" width="200"/>
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/112-29-a-little-glass-of-fascination/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="112.29 A little glass of fascination" class="fusion-link-wrapper" href="https://www.smws.com.au/product/112-29-a-little-glass-of-fascination/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/112-29-a-little-glass-of-fascination/">
# 		112.29 A little glass of fascination	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>219.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31308 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-peated membership-content purchase-restricted product-grid-view instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/122.23-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/122.23-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/122.23-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/122.23.png 400w" width="200"/>
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/122-23-highly-a-musing/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="122.23 ‘Highly a-musing’" class="fusion-link-wrapper" href="https://www.smws.com.au/product/122-23-highly-a-musing/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/122-23-highly-a-musing/">
# 		122.23 ‘Highly a-musing’	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>160.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31306 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-deep-rich-dried-fruits membership-content purchase-restricted product-grid-view instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/9.149-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/9.149-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/9.149-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/9.149.png 400w" width="200"/>
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/9-149-delightful-gravitas/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="9.149 Delightful gravitas" class="fusion-link-wrapper" href="https://www.smws.com.au/product/9-149-delightful-gravitas/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/9-149-delightful-gravitas/">
# 		9.149 Delightful gravitas	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>495.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31301 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-juicy-oak-vanilla membership-content purchase-restricted product-grid-view last instock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/54.67-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/54.67-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/54.67-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/54.67.png 400w" width="200"/>
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/54-67-sensational-sipping/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="54.67 Sensational sipping" class="fusion-link-wrapper" href="https://www.smws.com.au/product/54-67-sensational-sipping/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/54-67-sensational-sipping/">
# 		54.67 Sensational sipping	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>235.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31304 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-deep-rich-dried-fruits membership-content purchase-restricted product-grid-view first outofstock taxable shipping-taxable product-type-simple">
# <div class="fusion-clean-product-image-wrapper ">
# <div aria-haspopup="true" class="fusion-image-wrapper fusion-image-size-fixed">
# <div class="container-image-and-badge "><img alt="" class="attachment-shop_catalog size-shop_catalog wp-post-image" height="300" sizes="(max-width: 200px) 100vw, 200px" src="https://www.smws.com.au/wp-content/uploads/2018/11/72.64-200x300.png" srcset="https://www.smws.com.au/wp-content/uploads/2018/11/72.64-100x150.png 100w, https://www.smws.com.au/wp-content/uploads/2018/11/72.64-200x300.png 200w, https://www.smws.com.au/wp-content/uploads/2018/11/72.64.png 400w" width="200"/> <div class="yith-wcbm-badge yith-wcbm-badge-image yith-wcbm-badge-17855" data-position='{"top":"auto","bottom":0,"left":"calc(50% - 55px)","right":"auto"}'>
# <div class="yith-wcbm-badge__wrap">
# <img alt="" src="//www.smws.com.au/wp-content/uploads/2018/01/STAMP-dearly-departed-red-web.png"/> </div><!--yith-wcbm-badge__wrap-->
# </div><!--yith-wcbm-badge-->
# </div><!--container-image-and-badge-->
# <div class="fusion-rollover">
# <div class="fusion-rollover-content">
# <div class="cart-loading">
# <a href="https://www.smws.com.au/cart/">
# <i class="fusion-icon-spinner"></i>
# <div class="view-cart">View Cart</div>
# </a>
# </div>
# <div class="fusion-product-buttons">
# <a class="show_details_button" href="https://www.smws.com.au/product/72-64-all-sweetness-and-fight/" style="float:none;max-width:none;text-align:center;">
# 	Details</a>
# </div>
# <a aria-label="72.64 All sweetness and fight" class="fusion-link-wrapper" href="https://www.smws.com.au/product/72-64-all-sweetness-and-fight/"></a>
# </div>
# </div>
# </div>
# </div>
# <div class="fusion-product-content">
# <div class="product-details">
# <div class="product-details-container">
# <h3 class="product-title">
# <a href="https://www.smws.com.au/product/72-64-all-sweetness-and-fight/">
# 		72.64 All sweetness and fight	</a>
# </h3>
# <div class="fusion-price-rating">
# <span class="price"><span class="woocommerce-Price-amount amount"><span class="woocommerce-Price-currencySymbol">$</span>199.00</span> <small class="woocommerce-price-suffix">inc. GST</small></span>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="post-31309 product type-product status-publish has-post-thumbnail product_cat-all-whisky product_cat-cask-number product_cat-flavour-profiles product_cat-peated membership-content purchase-restricted product-grid-view instock taxable shipping-taxable product-type-simple">
# ...
# 						jQuery.get( ajaxurl, { 'action': 'fusion_login_nonce' }, function( response ) {
# 							jQuery( '.fusion-login-nonce' ).html( response );
# 						});
# 					}
# 				});
# 				</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org\/","@graph":[{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/4-238-surrender-your-soul\/","name":"4.238 Surrender your soul","url":"https:\/\/www.smws.com.au\/product\/4-238-surrender-your-soul\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/68-18-triple-berry-lamington-cake\/","name":"68.18 Triple berry Lamington cake","url":"https:\/\/www.smws.com.au\/product\/68-18-triple-berry-lamington-cake\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/around-the-world-in-three-bottles\/","name":"Around the world in three bottles","url":"https:\/\/www.smws.com.au\/product\/around-the-world-in-three-bottles\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/c6-1-wood-fired-wonder-juice-cognac\/","name":"C6.1 Wood fired wonder juice (Cognac)","url":"https:\/\/www.smws.com.au\/product\/c6-1-wood-fired-wonder-juice-cognac\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/feis-ile-twin-pack\/","name":"Feis Ile Twin Pack","url":"https:\/\/www.smws.com.au\/product\/feis-ile-twin-pack\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/93-92-fruit-pie-in-a-cleaning-cupboard-2\/","name":"93.92 Fruit pie in a cleaning cupboard","url":"https:\/\/www.smws.com.au\/product\/93-92-fruit-pie-in-a-cleaning-cupboard-2\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/123-26-blossom-falling-onto-sponge-cake\/","name":"123.26 Blossom falling onto sponge cake","url":"https:\/\/www.smws.com.au\/product\/123-26-blossom-falling-onto-sponge-cake\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/a4-1-elegant-and-inviting-armagnac\/","name":"A4.1 Elegant and inviting (Armagnac)","url":"https:\/\/www.smws.com.au\/product\/a4-1-elegant-and-inviting-armagnac\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/12-16-moonlight-in-new-york\/","name":"12.16 Moonlight in New York","url":"https:\/\/www.smws.com.au\/product\/12-16-moonlight-in-new-york\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/26-123-attractive-lively-fun\/","name":"26.123 Attractive, lively fun","url":"https:\/\/www.smws.com.au\/product\/26-123-attractive-lively-fun\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/b3-4-bucking-bronco\/","name":"B3.4 Bucking bronco","url":"https:\/\/www.smws.com.au\/product\/b3-4-bucking-bronco\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/135-7-yoghurt-and-fruit-candies\/","name":"135.7 Yoghurt and fruit candies","url":"https:\/\/www.smws.com.au\/product\/135-7-yoghurt-and-fruit-candies\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/112-29-a-little-glass-of-fascination\/","name":"112.29 A little glass of fascination","url":"https:\/\/www.smws.com.au\/product\/112-29-a-little-glass-of-fascination\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/122-23-highly-a-musing\/","name":"122.23 \u2018Highly a-musing\u2019","url":"https:\/\/www.smws.com.au\/product\/122-23-highly-a-musing\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/9-149-delightful-gravitas\/","name":"9.149 Delightful gravitas","url":"https:\/\/www.smws.com.au\/product\/9-149-delightful-gravitas\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/54-67-sensational-sipping\/","name":"54.67 Sensational sipping","url":"https:\/\/www.smws.com.au\/product\/54-67-sensational-sipping\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/72-64-all-sweetness-and-fight\/","name":"72.64 All sweetness and fight","url":"https:\/\/www.smws.com.au\/product\/72-64-all-sweetness-and-fight\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/53-259-succumb-to-desire\/","name":"53.259 Succumb to desire","url":"https:\/\/www.smws.com.au\/product\/53-259-succumb-to-desire\/"},{"@type":"Product","@id":"https:\/\/www.smws.com.au\/product\/112-31-one-for-the-low-road\/","name":"1 ...
# 		var c = document.body.className;
# 		c = c.replace(/woocommerce-no-js/, 'woocommerce-js');
# 		document.body.className = c;
# 	</script>
# <script src="http://www.smws.com.au/wp-content/plugins/event-tickets-plus/vendor/jquery.cookie/jquery.cookie.js?ver=4.8.3" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-content/plugins/event-tickets-plus/vendor/jquery.deparam/jquery.deparam.js?ver=4.8.3" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-content/plugins/event-tickets-plus/src/resources/js/meta.min.js?ver=4.8.3" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-content/plugins/event-tickets-plus/src/resources/js/attendees-list.min.js?ver=4.8.3" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/jquery-blockui/jquery.blockUI.min.js?ver=2.70" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/js-cookie/js.cookie.min.js?ver=2.1.4" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var woocommerce_params = {"ajax_url":"\/wp-admin\/admin-ajax.php","wc_ajax_url":"\/?wc-ajax=%%endpoint%%","min_password_strength":"1","i18n_password_error":"<span class=\"mr-red\">Please enter a stronger password.<\/span>","i18n_password_hint":"Your password must be at least <strong>6 characters long.<\/strong> To make it stronger, use upper and lower case letters, numbers and symbols."};
# /* ]]> */
# </script>
# <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/frontend/woocommerce.min.js?ver=3.5.1" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var wc_cart_fragments_params = {"ajax_url":"\/wp-admin\/admin-ajax.php","wc_ajax_url":"\/?wc-ajax=%%endpoint%%","cart_hash_key":"wc_cart_hash_db8d27fdf6a5e3805b8971c318fccf31","fragment_name":"wc_fragments_db8d27fdf6a5e3805b8971c318fccf31","min_password_strength":"1","i18n_password_error":"<span class=\"mr-red\">Please enter a stronger password.<\/span>","i18n_password_hint":"Your password must be at least <strong>6 characters long.<\/strong> To make it stronger, use upper and lower case letters, numbers and symbols."};
# /* ]]> */
# </script>
# <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/frontend/cart-fragments.min.js?ver=3.5.1" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var mailchimp_public_data = {"site_url":"http:\/\/www.smws.com.au","ajax_url":"https:\/\/www.smws.com.au\/wp-admin\/admin-ajax.php"};
# /* ]]> */
# </script>
# <script src="http://www.smws.com.au/wp-content/plugins/mailchimp-for-woocommerce/public/js/mailchimp-woocommerce-public.min.js?ver=2.1.11" type="text/javascript"></script>
# <script src="https://chimpstatic.com/mcjs-connected/js/users/1467ca1f7000eaf593230360d/9c8de063ae1b03f5d4864f152.js?ver=2.1.11" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-content/themes/Avada-Child-Theme/js/magnific-popup.min.js" type="text/javascript"></script>
# <!--[if IE 9]>
# <script type='text/javascript' src='http://www.smws.com.au/wp-content/themes/Avada/includes/lib/assets/min/js/general/fusion-ie9.js?ver=1'></script>
# <![endif]-->
# <script src="http://www.smws.com.au/wp-content/uploads/fusion-scripts/289db04c06e300227b9381645134cfd5.min.js" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-includes/js/wp-embed.min.js?ver=4.9.9" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-includes/js/jquery/ui/mouse.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-includes/js/jquery/ui/slider.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/jquery-ui-touch-punch/jquery-ui-touch-punch.min.js?ver=3.5.1" type="text/javascript"></script>
# <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/accounting/accounting.min.js?ver=0.4.2" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var woocommerce_price_slider_params = {"currency_format_num_decimals":"0","currency_format_symbol":"$","currency_format_decimal_sep":".","currency_format_thousand_sep":",","currency_format":"%s%v"};
# /* ]]> */
# </script>
# <script src="http://www.smws.com.au/wp-content/plugins/woocommerce/assets/js/frontend/price-slider.min.js?ver=3.5.1" type="text/javascript"></script>
# <!-- WooCommerce JavaScript -->
# <script type="text/javascript">
# jQuery(function($) {
#
# 			$( '.add_to_cart_button:not(.product_type_variable, .product_type_grouped)' ).click( function() {
# 				ga('send', 'event', 'Products', 'Add to Cart', ($(this).data('product_sku')) ? ($(this).data('product_sku')) : ('#' + $(this).data('product_id')));
# 			});
#
#
# ga( 'send', 'pageview' );
#  });
# </script>
# <div class="post-content woocommerce mfp-hide" id="register-lightbox">
# <h2>Register as a Taster!</h2>
# <form action="https://www.smws.com.au/shop/" class="wppb-user-forms wppb-register-user wppb-user-logged-out" enctype="multipart/form-data" id="wppb-register-user-lightbox" method="post">
# <ul><li class="wppb-form-field wppb-default-name-heading" id="wppb-form-element-24"><h4>My Profile</h4><span class="wppb-description-delimiter "></span></li><li class="wppb-form-field wppb-default-display-name-publicly-as" id="wppb-form-element-6"></li><li class="wppb-form-field wppb-select" id="wppb-form-element-17">
# <label for="salutation_title">Title</label>
# <select class="custom_field_select" id="salutation_title" name="salutation_title"><option class="custom_field_select_option " selected="" value="Mr">Mr</option><option class="custom_field_select_option " value="Mrs">Mrs</option><option class="custom_field_select_option " value="Ms">Ms</option><option class="custom_field_select_option " value="Miss">Miss</option><option class="custom_field_select_option " value="Dr">Dr</option><option class="custom_field_select_option " value="Prof">Prof</option>
# </select></li><li class="wppb-form-field wppb-default-first-name" id="wppb-form-element-27">
# <label for="first_name">First Name<span class="wppb-required" title="This field is required">*</span></label>
# <input class="text-input default_field_firstname " id="first_name" maxlength="70" name="first_name" required="" type="text" value=""/></li><li class="wppb-form-field wppb-default-last-name" id="wppb-form-element-28">
# <label for="last_name">Surname<span class="wppb-required" title="This field is required">*</span></label>
# <input class="text-input default_field_lastname " id="last_name" maxlength="70" name="last_name" required="" type="text" value=""/></li><li class="wppb-form-field wppb-default-nickname" id="wppb-form-element-5">
# <label for="nickname">Nickname</label>
# <input class="text-input default_field_nickname " id="nickname" maxlength="70" name="nickname" type="text" value=""/></li><li class="wppb-form-field wppb-avatar" id="wppb-form-element-20"><label for="avatar_upload">Profile Picture</label><a class="button wppb_upload_button" data-multiple_upload="false" data-upload_input="avatar_upload" data-upload_mn="avatar_upload" data-uploader_button_text="Select File" data-uploader_title="Profile Picture" href="#" id="upload_avatar_upload_button">Upload </a><input id="avatar_upload" name="avatar_upload" size="36" type="hidden" value=""/><span class="wppb-description-delimiter">Upload your Avatar. Supported file types are JPG, GIF &amp; PNG.</span></li><li class="wppb-form-field wppb-default-contact-info-heading" id="wppb-form-element-25"><h4>My Contact Details</h4><span class="wppb-description-delimiter "></span></li><li class="wppb-form-field wppb-default-e-mail" id="wppb-form-element-8">
# <label for="email">E-mail<span class="wppb-required" title="This field is required">*</span></label>
# <input class="text-input default_field_email " id="email" maxlength="70" name="email" required="" type="email" value=""/></li><li class="wppb-form-field wppb-input" id="wppb-form-element-31">
# <label for="phone_number">Phone</label>
# <input class="extra_field_input " id="phone_number" maxlength="70" name="phone_number" type="text" value=""/></li><li class="wppb-form-field wppb-input" id="wppb-form-element-22">
# <label for="mobile_number">Mobile</label>
# <input class="extra_field_input " id="mobile_number" maxlength="70" name="mobile_number" type="text" value=""/></li><li class="wppb-form-field wppb-woocommerce-customer-billing-address" id="wppb-form-element-32"></li><li class="wppb-form-field wppb-default-about-yourself-heading" id="wppb-form-element-26"><h4>Username / Password</h4><span class="wppb-description-delimiter "></span></li><li class="wppb-form-field wppb-default-username" id="wppb-form-element-2">
# <label for="username">Username<span class="wppb-required" title="This field is required">*</span></label>
# <input class="text-input default_field_username " id="username" maxlength="70" name="username" required="" type="text" value=""/><span class="wppb-description-delimiter">Usernames cannot be changed.</span></li><li class="wppb-form-field wppb-default-password" id="wppb-form-element-15">
# <label for="passw1">Password<span class="wppb-required" title="This field is required">*</span></label>
# <input autocomplete="off" class="text-input " id="passw1" maxlength="70" name="passw1" required="" type="password" value=""/><span class="wppb-description-delimiter">Type your password. Minimum length of 5 characters. <br>The password must have a minimum strength of Very Weak.</br></span><span id="pass-strength-result">Strength indicator</span>
# <input id="wppb_password_strength" name="wppb_password_strength" type="hidden" value=""/></li><li class="wppb-form-field wppb-default-repeat-password" id="wppb-form-element-16">
# <label for="passw2">Repeat Password<span class="wppb-required" title="This field is required">*</span></label>
# <input autocomplete="off" class="text-input " id="passw2" maxlength="70" name="passw2" required="" type="password" value=""/><span class="wppb-description-delimiter">Type your password again. </span></li><li class="wppb-form-field wppb-mailchimp-subscribe" id="wppb-form-element-33"><label for="custom_field_mailchimp_subscribe_33"><input checked="checked" class="extra_field_mailchimp" id="custom_field_mailchimp_subscribe_33" name="custom_field_mailchimp_subscribe_33" type="checkbox" value="528b1d47d5"/>Subscribe to Newsletter</label></li></ul><ul><li class="wppb-form-field wppb-send-credentials-checkbox"><label for="send_credentials_via_email"><input id="send_credentials_via_email" name="send_credentials_via_email" type="checkbox" value="sending"/>Send these credentials via email.</label></li></ul> <p class="form-submit">
# <input class="submit button" id="register" name="register" type="submit" value="Register"/>
# <input id="action" name="action" type="hidden" value="register"/>
# <input id="form_name" name="form_name" type="hidden" value="lightbox"/>
# <input name="wppb_referer_url" type="hidden" value=""/> </p><!-- .form-submit -->
# <input id="register_lightbox_nonce_field" name="register_lightbox_nonce_field" type="hidden" value="7fb2e145dd"/><input name="_wp_http_referer" type="hidden" value="/shop/"/> </form>
# </div>
# <script>
# jQuery( '.open-register-lightbox' ).magnificPopup({
# 	type: 'inline',
# 	midClick: true,
# 	closeBtnInside: true
# });
# jQuery( '.fusion-menu-login-box-register' ).magnificPopup({
# 	items: {
# 		type: 'inline',
# 		src: '#register-lightbox'
# 	},
# 	closeBtnInside: true,
# 	midClick: true
# });
# </script> </body>

# %% [markdown]
# We can certainly pull a lot of links easily with their navigation system. Here is one way.

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# #content
# /cdn-cgi/l/email-protection#7e585d4f4e4b45585d4f4f4e4518585d4f4f4f45585d484a450d13585d4f4f47450d50585d474745585d4f4f4f45585d4f4e4745501f0b
# https://www.facebook.com/Australiansmws
# https://www.instagram.com/smws_aus/
# https://twitter.com/SMWS_Australia
# https://www.linkedin.com/company/scotch-malt-whisky-society-australia
# https://www.smws.com.au/
# https://www.smws.com.au/
# https://www.smws.com.au/shop/
# #
# https://www.smws.com.au/membership/
# https://www.smws.com.au/product/smws-annual-membership-subscription/
# https://www.smws.com.au/product/smws-gift-membership/
# https://www.smws.com.au/society/
# https://www.smws.com.au/news/
# https://www.smws.com.au/outturn-magazine-2/
# https://www.smws.com.au/unfiltered-magazine/
# https://www.smws.com.au/frequently-asked-questions/
# https://www.smws.com.au/our-unique-whisky/
# https://www.smws.com.au/our-events/
# https://www.smws.com.au/tasting-panel/
# https://www.smws.com.au/corporate-private-functions/
# https://www.smws.com.au/our-team/
# https://www.smws.com.au/partner-bars/
# https://www.smws.com.au/smws-worldwide/
# https://www.smws.com.au/smws-worldwide-2/
# https://www.smws.com.au/events/
# https://www.smws.com.au/news/
# https://www.smws.com.au/contact-us/
# https://www.smws.com.au/my-account/
# https://www.smws.com.au/my-account/
# https://www.smws.com.au/cart/
# https://www.smws.com.au
# None
# ?product_orderby=name
# ?product_orderby=price
# ?product_orderby=date
# ?product_orderby=popularity
# ?product_order=asc
# None
# ?product_count=20
# ?product_count=40
# ?product_count=60
# ?product_view=grid
# ?product_view=list
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/4-238-surrender-your-soul/
# https://www.smws.com.au/product/4-238-surrender-your-soul/
# https://www.smws.com.au/product/4-238-surrender-your-soul/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/68-18-triple-berry-lamington-cake/
# https://www.smws.com.au/product/68-18-triple-berry-lamington-cake/
# https://www.smws.com.au/product/68-18-triple-berry-lamington-cake/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/around-the-world-in-three-bottles/
# https://www.smws.com.au/product/around-the-world-in-three-bottles/
# https://www.smws.com.au/product/around-the-world-in-three-bottles/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/c6-1-wood-fired-wonder-juice-cognac/
# https://www.smws.com.au/product/c6-1-wood-fired-wonder-juice-cognac/
# https://www.smws.com.au/product/c6-1-wood-fired-wonder-juice-cognac/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/feis-ile-twin-pack/
# https://www.smws.com.au/product/feis-ile-twin-pack/
# https://www.smws.com.au/product/feis-ile-twin-pack/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/93-92-fruit-pie-in-a-cleaning-cupboard-2/
# https://www.smws.com.au/product/93-92-fruit-pie-in-a-cleaning-cupboard-2/
# https://www.smws.com.au/product/93-92-fruit-pie-in-a-cleaning-cupboard-2/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/123-26-blossom-falling-onto-sponge-cake/
# https://www.smws.com.au/product/123-26-blossom-falling-onto-sponge-cake/
# https://www.smws.com.au/product/123-26-blossom-falling-onto-sponge-cake/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/a4-1-elegant-and-inviting-armagnac/
# https://www.smws.com.au/product/a4-1-elegant-and-inviting-armagnac/
# https://www.smws.com.au/product/a4-1-elegant-and-inviting-armagnac/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/12-16-moonlight-in-new-york/
# https://www.smws.com.au/product/12-16-moonlight-in-new-york/
# https://www.smws.com.au/product/12-16-moonlight-in-new-york/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/26-123-attractive-lively-fun/
# https://www.smws.com.au/product/26-123-attractive-lively-fun/
# https://www.smws.com.au/product/26-123-attractive-lively-fun/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/b3-4-bucking-bronco/
# https://www.smws.com.au/product/b3-4-bucking-bronco/
# https://www.smws.com.au/product/b3-4-bucking-bronco/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/135-7-yoghurt-and-fruit-candies/
# https://www.smws.com.au/product/135-7-yoghurt-and-fruit-candies/
# https://www.smws.com.au/product/135-7-yoghurt-and-fruit-candies/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/112-29-a-little-glass-of-fascination/
# https://www.smws.com.au/product/112-29-a-little-glass-of-fascination/
# https://www.smws.com.au/product/112-29-a-little-glass-of-fascination/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/122-23-highly-a-musing/
# https://www.smws.com.au/product/122-23-highly-a-musing/
# https://www.smws.com.au/product/122-23-highly-a-musing/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/9-149-delightful-gravitas/
# https://www.smws.com.au/product/9-149-delightful-gravitas/
# https://www.smws.com.au/product/9-149-delightful-gravitas/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/54-67-sensational-sipping/
# https://www.smws.com.au/product/54-67-sensational-sipping/
# https://www.smws.com.au/product/54-67-sensational-sipping/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/72-64-all-sweetness-and-fight/
# https://www.smws.com.au/product/72-64-all-sweetness-and-fight/
# https://www.smws.com.au/product/72-64-all-sweetness-and-fight/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/53-259-succumb-to-desire/
# https://www.smws.com.au/product/53-259-succumb-to-desire/
# https://www.smws.com.au/product/53-259-succumb-to-desire/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/112-31-one-for-the-low-road/
# https://www.smws.com.au/product/112-31-one-for-the-low-road/
# https://www.smws.com.au/product/112-31-one-for-the-low-road/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/product/35-211-putting-on-the-ritz/
# https://www.smws.com.au/product/35-211-putting-on-the-ritz/
# https://www.smws.com.au/product/35-211-putting-on-the-ritz/
# https://www.smws.com.au/shop/page/2/
# https://www.smws.com.au/shop/page/3/
# https://www.smws.com.au/shop/page/2/
# https://www.smws.com.au/product-category/all-whisky/
# https://www.smws.com.au/product-category/cask-number/
# https://www.smws.com.au/product-category/flavour-profiles/
# https://www.smws.com.au/product-category/single-cask-spirits/
# https://www.smws.com.au/product-category/membership/
# https://www.smws.com.au/product-category/gift-range/
# https://www.smws.com.au/my-account/
# https://www.smws.com.au/account-page/
# https://www.smws.com.au/cart/
# https://www.smws.com.au/checkout/
# https://www.smws.com.au/shop/
# http://artsmart.com.au
# https://www.facebook.com/Australiansmws
# https://www.instagram.com/smws_aus/
# https://twitter.com/SMWS_Australia
# https://www.linkedin.com/company/scotch-malt-whisky-society-australia
# None
# #

# %% [markdown]
# It looks like there are a few tables in there as well.
# ### Nope
# SMWS doesn't use tables

# %%
soup.body.table

# %%
len(soup.find_all('table'))
# Out:
# 0

# %%
prods = soup.find_all('h3', _class=['product-title'])#, class_=['product_details'])
prods[-40:]
# Out:
# []

# %% [markdown]
# 65 items for that selector. And 65 bottles on the page. That could be it.
#
# When we use select, Beautiful Soup gives us a list. So let's look at the list elements.

# %%
soup.select(".v-product")[0]

# %% [markdown]
# So when we use the CSS selector, we get a list where each item in the list is one of our scotch listings. How can we pull some meaning full data from that? I would like to get the name, link to the product, and the pricing info. Let's get one item to work with so we can try to parse this out.

# %%
prods = soup.find_all("div", _class="product-details")
prods
# Out:
# []

# %%
prods
# Out:
# []

# %%
table[1]

# %%
scotch = table[0]
scotch

# %%
scotch.a

# %%
scotch.a.string

# %%
scotch.a.text

# %% [markdown]
# None of that is particularly useful. Let's try working with the CSS selectors again.

# %%
scotch.select(".v-product__title")

# %%
scotch.select(".v-product__title").text

# %% [markdown]
# Ooops. Remember select returns a list.

# %%
scotch.select(".v-product__title")[0].text

# %% [markdown]
# Now we are getting somewhere.

# %%
scotch.select(".product_productprice")[0]

# %%
scotch.select(".product_productprice")[0].text

# %%
scotch.select(".product_saleprice")[0].text

# %%
scotch.select(".product_listprice")[0].text

# %% [markdown]
# Now what about the product link?

# %%
scotch.select(".v-product__title")[0].get('href')

# %% [markdown]
# That's it!  [https://www.drinkupny.com/Aberlour-a-bunadh-p/s0958.htm](https://www.drinkupny.com/Aberlour-a-bunadh-p/s0958.htm)

# %% [markdown]
# Now we can manipulate our strings a bit to strip off the parts we don't want.

# %%
scotch.select(".v-product__title")[0].text.split('\n', 1)[1]

# %%
scotch.select(".v-product__title")[0].text.split('\n', 1)[1].strip()

# %%
scotch.select(".v-product__title")[0].text.strip()

# %%
scotch.select(".product_productprice")[0].text.split('$', 1)[1]

# %%
scotch.select(".product_productprice")[0].text.split('$', 1)[1].strip()

# %%
scotch.select(".product_saleprice")[0].text.split('$', 1)[1].strip()

# %%
scotch.select(".product_listprice")[0].text.split('$', 1)[1].strip()

# %% [markdown]
# Let's pull it all together and see if it works for parsing all of the data.

# %%
len(table)

# %%
import pandas as pd

# %%
i = 0
column_names = ['name', 'url', 'regular_price', 'our_price', 'sale_price']

df = pd.DataFrame(columns = column_names)

# %%
while i < len(table):
    new_scotch = pd.Series([table[i].select(".v-product__title")[0].text.strip(), \
                                 table[i].select(".v-product__title")[0].get('href'), \
                                 table[i].select(".product_listprice")[0].text.split('$', 1)[1], \
                                 table[i].select(".product_productprice")[0].text.split('$', 1)[1], \
                                 table[i].select(".product_saleprice")[0].text.split('$', 1)[1]], column_names)
    df = df.append(new_scotch, ignore_index = True)
    i += 1

# %% [markdown]
# No errors, so that is a good sign. Can we now can easily compare Scotch prices?

# %%
df

# %% [markdown]
# If you went through this notebook instead of trying a page you wanted to scrape, I fully expect you to go try and scrape your own page now!

# %% [markdown]
# If you are interested in working with [scrapy](https://doc.scrapy.org/en/latest/index.html), I highly recommend starting with the [tutorial](https://doc.scrapy.org/en/latest/intro/tutorial.html). I have provided a [scrapy sample](./scrapy/scotch) that uses scrapy to begin pulling data from the site utilized here.
